# %% [markdown]
# # Data Visualization in Python - Matplotlib

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib is a plotting library for the Python that is highly customizable and provides a great control on every element in a plot.

# %% [markdown]
# ___
# ## Section I - Basic Plots

# %% [markdown]
# Importing matplotlib using its general alias

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# Specifying so will output our plots and stores within the notebook. Also, this eliminates the need of writing `plt.show()` which you'd need if you are using a different editor.

# %%
# %matplotlib inline

# %% [markdown]
# Matplotlib supports two ways of creating plots.
#
# 1. Function
# 2. Object Oriented

# %% [markdown]
# ___
# ## Section II - Functional Approach

# %%
x = np.arange(-4, 5, 1)
y = x + 2

# %%
x
# Out:
# array([-4, -3, -2, -1,  0,  1,  2,  3,  4])

# %%
y
# Out:
# array([-2, -1,  0,  1,  2,  3,  4,  5,  6])

# %%
plt.plot(x, y) 

# Label the axes
plt.xlabel('X-value')
plt.ylabel('Squared value')
plt.title('Parabola')

# %% [markdown]
# ### Multiplots in same figure

# %% [markdown]
# 'subplot()' takes the arguments number of rows, number of cols and index of the subplot.
#
# <br>
# <u> Syntax </u>: plt.subplot(nrows, ncols, index)

# %%
# Plot 1
plt.subplot(1,2,1)
plt.plot(x, y, 'r')

# Plot 2
plt.subplot(1,2,2)
plt.plot(y, x, 'g');

# %% [markdown]
# ___
# ##  Section III - Object Oriented Method
#
# We instantiate figure objects and then call methods or attributes on that object. Useful when you need multiple plots on one figure

# %%
# Create a figure (empty canvas)
fig = plt.figure(figsize=(8,6))

# Add set of axes to figure
axes = fig.add_axes([1, 1, 1, 1]) 

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('X value') # xlabel vs set_xlabel
axes.set_ylabel('Squared Value')

# %% [markdown]
# ### Legend

# %% [markdown]
# legend() to add a legend. It takes loc as an argument.

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_axes([1,1,1,1])

ax.plot(x, x, 'b', label="x")
ax.plot(x, y, 'g', label="y")
ax.legend(loc = 0)

# %% [markdown]
# best	     - 0
# upper right	 - 1
# upper left	 - 2
# lower left	 - 3
# lower right	 - 4
# right	     - 5
# center left	 - 6
# center right - 7
# lower center - 8
# upper center - 9
# center	     - 10

# %% [markdown]
# Did you notice anything different in the above plot ?
#
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# .<br>
# I skipped adding the label !!!!

# %% [markdown]
# ### Multiplot - Plot inside a plot

# %%
fig = plt.figure(figsize=(8,6))

axes1 = fig.add_axes([1, 1, 1, 1]) # main axes
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# %%
fig = plt.figure(figsize=(8,6))

axes2 = fig.add_axes([1, 1, 1, 1]) # inset axes
axes2.plot(x, x**2, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %%
# Creates blank canvas
fig = plt.figure(figsize=(8,6))

axes1 = fig.add_axes([1, 1, 1, 1]) # main axes
axes2 = fig.add_axes([1.08, 1.8, 0.15, 0.15]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X')
axes1.set_ylabel('Y')
axes1.set_title('Line')

# Insert Figure Axes 2
axes2.plot(x, x**2, 'r')
axes2.set_xlabel('X')
axes2.set_ylabel('Y^2')
axes2.set_title('Parabola')

# %% [markdown]
# ___
# ## Section IV - Formatting the plots

# %% [markdown]
# ### Figure size and DPI

# %% [markdown]
# You can adjust the dots per inch (DPI) by using `figsize` and `dpi` keyword arguments.
# * `figsize` accpets width and height of the figure in inches
# * `dpi` accpts number of pixels per inch (dots-per-inch)

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %% [markdown]
# The same arguments can also be passed to layout managers, such as the `subplots` function:

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, x**2, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')

# %% [markdown]
# ### Export figures
#
# Matplotlib supports formats such as PNG, JPG, EPS, SVG, PGF and PDF to save your figure.

# %% [markdown]
# To save a figure to a file we can use the `savefig` method in the `Figure` class:

# %%
fig.savefig("plot.png")

# %% [markdown]
# ### Setting colors and style

# %% [markdown]
# Matplotlib supports 'MATLAB-like' syntax to modify colors and styles of your plots.
#
# 1. `'b--'` means blue dashed line
# 2. `'g.'`  means green line with marker

# %% [markdown]
# Colors -
#
#         b: blue
#         g: green
#         r: red
#         c: cyan
#         m: magenta
#         y: yellow
#         k: black
#         w: white
#
# Styles -
#
#         '-'  solid line style
#         '--' dashed line style
#         '-.' dash-dot line style
#         ':'  dotted line style
#         '.'  point marker
#         ','  pixel marker
#         'o'  circle marker

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2, 'b.-') # blue line with marker
ax.plot(x, x**3, 'g--') # green dashed line

# %% [markdown]
# ### Colors using hexadecimal code

# %% [markdown]
# You can also use color names or RGB hexadecimal codes to color your plot. Matplotlib also supports tuning the tranparancy of the line by changing alpha.

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.5) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code

# %% [markdown]
# ___
# ## Section V - Logarithmic scale

# %% [markdown]
# Often in real world datasets, your data will not be on the same scale.
#
# * For example: I am currently solving using a bank's marketing dataset to predict if a customer is likely to accept or reject an offer based on features like 'GDP Growth' of the city the customer lives in, 'Annual Salary' etc.
#
# The GDP growth can vary between 1 to 5 whereas the salary can range from 50,000 to 500,000.
#
# There is a huge different in the scale. Situations like these would require you to use 'logarithmic' scale.

# %% [markdown]
# You can set a logarithmic scale for one or both axes using `set_xscale` and `set_yscale` methods

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x, x, np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");

# %% [markdown]
# ___
# ## Section VI - Ticks and tick labels

# %%
x = np.arange(0,11,1)
y = x**2

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(x, x**2, x, x**3, lw=2)

ax.set_xticks([1, 4, 7, 9, 10])
ax.set_xticklabels(['Tinker', 'Tailor', 'Soldier', 'Spy'], fontsize=18)

yticks = [0, 200, 400, 600, 800, 1000]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18); # LaTeX formatted labels

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(x, x**2, x, x**3, lw=2)
# Out:
# [<matplotlib.lines.Line2D at 0x12d9dcc0>,
#  <matplotlib.lines.Line2D at 0x13370d30>]
