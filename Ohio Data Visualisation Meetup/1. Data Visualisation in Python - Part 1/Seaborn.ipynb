# %% [markdown]
# # Data Visualization in Python - Seaborn

# %% [markdown]
# ## Seaborn
#
# A Python data visualization library built on matplotlib that helps plot attractive statistical graphs.

# %% [markdown]
# ___
# ## Section I - Numerical Plots
#
# To better understand the data, we need to understand the distribution of the data set. Seaborn provides distplot, jointplot, pairplot etc that help us understand the distributions

# %% [markdown]
# ### Importing Seaborn and Tips dataset

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### distplot
#
# The distplot shows the distribution of a univariate (single variable) data.

# %%
plt.figure(figsize=(12,10))
sns.distplot(tips['total_bill'])

# %% [markdown]
# You can remove the kde layer and specify the number of bins of interest

# %%
plt.figure(figsize=(12,10))
sns.distplot(tips['total_bill'],kde=False,bins=25)

# %% [markdown]
# ## jointplot
#
# jointplot() plots two distplots for bivariate (two variable) data.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, size = 10)

# %% [markdown]
# By default, jointplot uses a scatterplot between two variable. However, you can also choose your plot of interest by using the 'kind' parameter

# %% [markdown]
# 'kind' parameter accepts the following values:
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
# Jointplot with hexagonal bins
plt.figure(figsize=(12,10))
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex', size = 10)

# %%
# Jointplot with Regression and KDE
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg', size = 10)

# %% [markdown]
# You can see that when you use specify 'kind' = regression, 'jointplot' automatically specifies the p-value and  pearson correlation between the two variables.
#
# The band you see in the graph denotes the 95% confidence interval.

# %% [markdown]
# ## pairplot
#
# Helps plot pairwise relationships across entire dataframe (only for the numerical columns).

# %%
sns.pairplot(tips, size = 4)

# %% [markdown]
# However, it supports a color hue argument (for categorical columns).

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm', size = 4)

# %% [markdown]
# ___
# ## Section II - Categorical Plots

# %% [markdown]
# Categorical plots helps us plot categorical data. Seaborn provides countplot, barplot, boxplot, violinplot, stripplot, swarmplot etc that help us understand categorical data better.

# %% [markdown]
# ## countplot
#
# Helps plot the number of occurrences of each class in a categorical variable

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ## barplot
#
# Similar tp countplot but helps plot aggregation of categorical data based off statistical functions such as mean, standard deviation etc.

# %%
# Uses mean as an estimator by default 
plt.figure(figsize=(7,5))
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
plt.figure(figsize=(7,5))
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %% [markdown]
# You can get rid of the vertical bars by specifying 'ci = None'. By default ci takes 95 which represents 95% confidence interval.

# %%
sns.barplot(x=tips['sex'], y=tips['total_bill'], ci=None)

# %% [markdown]
# ## boxplot
#
# boxplots show the spread of the categorical data between variables or across classes (levels) of a categorical variable.

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x="day", y="total_bill", data=tips,palette='Set2')

# %% [markdown]
# ### Interpreting a box and whisker plot

# %% [markdown]
# ![title](img/boxplot.png)

# %% [markdown]
# **Median**
# The median (middle quartile) marks the mid-point of the data. Half the scores are greater than or equal to this value and half are less.
#
# **Inter-quartile range**
# The middle “box” represents the middle 50% of scores for the group. This is also referred to as the inter-quartile range.
#
# **Upper quartile**
# Seventy-five percent of the scores fall below the upper quartile.
#
# **Lower quartile**
# Twenty-five percent of scores fall below the lower quartile.
#
# **Whiskers**
# Whiskers often (but not always) stretch over a wider range of scores than the middle quartile groups.

# %% [markdown]
# **Relationship between Confidence Interval, Standard Deviation and Margin of Error**

# %% [markdown]
# If the data is normally distributed, the estimate represents the peak while the edges of the error bars represent the percentiles.

# %% [markdown]
# ![title](img/confidence interval.png)

# %% [markdown]
# The confidence interval represents the data within the 'Margin of Error' limits both above and below the estimate (in this case -- mean.)

# %% [markdown]
# ![title](img/moe.jpg)

# %% [markdown]
# Assuming the data is normally distributed, 68% of the observations should lie within the 1 standard deviation of the mean, 95% of them within  2 standard deviations while 99.7% data should be within 3 standard deviation.

# %% [markdown]
# ![title](img/bell curve.png)

# %%
# Hue variable helps differentiate different levels of the categorical variable
plt.figure(figsize=(7,5))
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %% [markdown]
# ## stripplot
#
# A strip plot is a good complement to a box plot in cases where you have small number of observations.

# %%
plt.figure(figsize=(7,5))
sns.stripplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# It is apparent that the total_bill is below $30 but it does not show 'how' apparent it is. We can use 'jitter' = True to know the distribution

# %%
plt.figure(figsize=(7,5))
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True)

# %% [markdown]
# ## swarmplot
#
# The swarmplot is similar to stripplot, but the points are adjusted so that they don’t overlap. This gives a better representation of the distribution, although it does not scale well for large numbers of observations

# %%
plt.figure(figsize=(7,5))
sns.swarmplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# ## violinplot
#
# A violin plot also shows the distribution of quantitative oe categorical data across several levels. However, violinplot uses 'kernal density estimation' to show the distribution of the data whereas boxplot features the actual datapoints.

# %%
plt.figure(figsize=(7,5))
sns.violinplot(x="day", y="total_bill", data=tips,palette='Set1')

# %% [markdown]
# You can also use 'hue' variable as well as 'split'

# %%
plt.figure(figsize=(7,5))
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')

# %%
plt.figure(figsize=(7,5))
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')

# %% [markdown]
# Why do I visualize in Python?
#
# (a) Coding - People have been managing other people for thousands of years. But here in the 21st century, many jobs have been already been automated.
#
# Think of it this way. Around 3.5 billion google searches are made everyday. Imagine how man hours would it take to do one google search. It's machines that carry out that work - not humans.
#
# It is no longer just about managing people. It's also about managing machines. How do you do that -- 'Coding'.
#
#
# (b) Are we in control of our decisions? - Not really. Here's an example.
# 		     There was this survey conducted on organ donation. And here are the results. We see that some contries have extremely high enrollment while others had extremely low. Organ donation also depends on the culture and sometimes even religion. But if you look at this plot countries that are similar actually exhibit very different behavior.
#
#              Sweden - Denmark
# 			 Germany - Austria
# 			 Netherlands - Belgium
# 			 UK - France.
#
# You see Netherlands here, the biggest among the small group, it got so far by mailing everyone "begging" to join organ donation.
# That means countries on the right did a better job than begging everyone.
# It all comes down to the form ta DMV:

# %% [markdown]
# ![title](img/a.jpg)

# %% [markdown]
# ![title](img/b.png)

# %% [markdown]
# Form A: Check the box if you want to participate in Organ Donation program (Don't participate and don't join)
#
# Form B: Check the box if you do not want to participate in Organ Donation program (Don't participate but join)
#
#
#
# So, it was not all about culture and religion. It was about the form that was presented to them.
#
# Similarly, it is not just about the data. It's also about visualization.
#
#
# Thank you.
