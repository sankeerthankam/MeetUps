# %% [markdown]
# ## XII. Case Study

# %% [markdown]
# ### Data:
#
# - Github User Collaboration Network
# - Nodes: Users
# - Edges: Collaboration on same Github repository
#
# ### Goal:
# 1. Analyze Structure
# 2. Visualize
# 3. Build Simple Recommendation System to connect users

# %%
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
nodes = [( 'u8746', { 'bipartite' : 'users' } ),
( 'u9802', { 'bipartite' : 'users' } ),
( 'u7670', { 'bipartite' : 'users' } ),
( 'u1221', { 'bipartite' : 'users' } ),
( 'u7644', { 'bipartite' : 'users' } ),
( 'u7549', { 'bipartite' : 'users' } ),
( 'u8709', { 'bipartite' : 'users' } ),
( 'u9571', { 'bipartite' : 'users' } ),
( 'u7821', { 'bipartite' : 'users' } ),
( 'u8721', { 'bipartite' : 'users' } ),
( 'u7326', { 'bipartite' : 'users' } ),
( 'u2737', { 'bipartite' : 'users' } ),
( 'u6743', { 'bipartite' : 'users' } ),
( 'u3430', { 'bipartite' : 'users' } ),
( 'u9575', { 'bipartite' : 'users' } ),
( 'u6603', { 'bipartite' : 'users' } ),
( 'u9971', { 'bipartite' : 'users' } ),
( 'u6367', { 'bipartite' : 'users' } ),
( 'u2882', { 'bipartite' : 'users' } ),
( 'u6607', { 'bipartite' : 'users' } ),
( 'u5822', { 'bipartite' : 'users' } ),
( 'u7074', { 'bipartite' : 'users' } ),
( 'u37', { 'bipartite' : 'users' } ),
( 'u5127', { 'bipartite' : 'users' } ),
( 'u2094', { 'bipartite' : 'users' } ),
( 'u8302', { 'bipartite' : 'users' } ),
( 'u6064', { 'bipartite' : 'users' } ),
( 'u9031', { 'bipartite' : 'users' } ),
( 'u4808', { 'bipartite' : 'users' } ),
( 'u4466', { 'bipartite' : 'users' } ),
( 'u583', { 'bipartite' : 'users' } ),
( 'u302', { 'bipartite' : 'users' } ),
( 'u3664', { 'bipartite' : 'users' } ),
( 'u733', { 'bipartite' : 'users' } ),
( 'u5740', { 'bipartite' : 'users' } ),
( 'u1569', { 'bipartite' : 'users' } ),
( 'u1423', { 'bipartite' : 'users' } ),
( 'u10110', { 'bipartite' : 'users' } ),
( 'u3821', { 'bipartite' : 'users' } ),
( 'u6055', { 'bipartite' : 'users' } ),
( 'u3483', { 'bipartite' : 'users' } ),
( 'u6533', { 'bipartite' : 'users' } ),
( 'u10428', { 'bipartite' : 'users' } ),
( 'u6784', { 'bipartite' : 'users' } ),
( 'u9566', { 'bipartite' : 'users' } ),
( 'u804', { 'bipartite' : 'users' } ),
( 'u5700', { 'bipartite' : 'users' } ),
( 'u3494', { 'bipartite' : 'users' } ),
( 'u2611', { 'bipartite' : 'users' } ),
( 'u726', { 'bipartite' : 'users' } ),
( 'u6201', { 'bipartite' : 'users' } ),
( 'u3907', { 'bipartite' : 'users' } ),
( 'u5162', { 'bipartite' : 'users' } ),
( 'u887', { 'bipartite' : 'users' } ),
( 'u666', { 'bipartite' : 'users' } ),
( 'u2325', { 'bipartite' : 'users' } ),
( 'u87', { 'bipartite' : 'users' } ),
( 'u816', { 'bipartite' : 'users' } ),
( 'u2509', { 'bipartite' : 'users' } ),
( 'u3411', { 'bipartite' : 'users' } ),
( 'u2225', { 'bipartite' : 'users' } ),
( 'u1566', { 'bipartite' : 'users' } ),
( 'u5298', { 'bipartite' : 'users' } ),
( 'u6061', { 'bipartite' : 'users' } ),
( 'u7712', { 'bipartite' : 'users' } ),
( 'u661', { 'bipartite' : 'users' } ),
( 'u10588', { 'bipartite' : 'users' } ),
( 'u2823', { 'bipartite' : 'users' } ),
( 'u8917', { 'bipartite' : 'users' } ),
( 'u3280', { 'bipartite' : 'users' } ),
( 'u4367', { 'bipartite' : 'users' } ),
( 'u2430', { 'bipartite' : 'users' } ),
( 'u4592', { 'bipartite' : 'users' } ),
( 'u1682', { 'bipartite' : 'users' } ),
( 'u2230', { 'bipartite' : 'users' } ),
( 'u2730', { 'bipartite' : 'users' } ),
( 'u1294', { 'bipartite' : 'users' } ),
( 'u4853', { 'bipartite' : 'users' } ),
( 'u3405', { 'bipartite' : 'users' } ),
( 'u133', { 'bipartite' : 'users' } ),
( 'u2263', { 'bipartite' : 'users' } ),
( 'u3989', { 'bipartite' : 'users' } ),
( 'u935', { 'bipartite' : 'users' } ),
( 'u1003', { 'bipartite' : 'users' } ),
( 'u21', { 'bipartite' : 'users' } ),
( 'u8783', { 'bipartite' : 'users' } ),
( 'u6955', { 'bipartite' : 'users' } ),
( 'u8992', { 'bipartite' : 'users' } ),
( 'u4256', { 'bipartite' : 'users' } ),
( 'u1978', { 'bipartite' : 'users' } ),
( 'u1940', { 'bipartite' : 'users' } ),
( 'u8729', { 'bipartite' : 'users' } ),
( 'u368', { 'bipartite' : 'users' } ),
( 'u272', { 'bipartite' : 'users' } ),
( 'u4176', { 'bipartite' : 'users' } ),
( 'u5895', { 'bipartite' : 'users' } ),
( 'u5470', { 'bipartite' : 'users' } ),
( 'u10143', { 'bipartite' : 'users' } ),
( 'u8722', { 'bipartite' : 'users' } ),
( 'u280', { 'bipartite' : 'users' } ),
( 'u8647', { 'bipartite' : 'users' } ),
( 'u621', { 'bipartite' : 'users' } ),
( 'u4593', { 'bipartite' : 'users' } ),
( 'u2583', { 'bipartite' : 'users' } ),
( 'u1045', { 'bipartite' : 'users' } ),
( 'u7251', { 'bipartite' : 'users' } ),
( 'u5040', { 'bipartite' : 'users' } ),
( 'u3274', { 'bipartite' : 'users' } ),
( 'u4071', { 'bipartite' : 'users' } ),
( 'u161', { 'bipartite' : 'users' } ),
( 'u8137', { 'bipartite' : 'users' } ),
( 'u844', { 'bipartite' : 'users' } ),
( 'u3509', { 'bipartite' : 'users' } ),
( 'u4189', { 'bipartite' : 'users' } ),
( 'u340', { 'bipartite' : 'users' } ),
( 'u876', { 'bipartite' : 'users' } ),
( 'u8518', { 'bipartite' : 'users' } ),
( 'u5604', { 'bipartite' : 'users' } ),
( 'u1436', { 'bipartite' : 'users' } ),
( 'u4392', { 'bipartite' : 'users' } ),
( 'u2644', { 'bipartite' : 'users' } ),
( 'u9558', { 'bipartite' : 'users' } ),
( 'u357', { 'bipartite' : 'users' } ),
( 'u88', { 'bipartite' : 'users' } ),
( 'u1259', { 'bipartite' : 'users' } ),
( 'u5731', { 'bipartite' : 'users' } ),
( 'u2056', { 'bipartite' : 'users' } ),
( 'u3415', { 'bipartite' : 'users' } ),
( 'u774', { 'bipartite' : 'users' } ),
( 'u7431', { 'bipartite' : 'users' } ),
( 'u5316', { 'bipartite' : 'users' } ),
( 'u4872', { 'bipartite' : 'users' } ),
( 'u5167', { 'bipartite' : 'users' } ),
( 'u9766', { 'bipartite' : 'users' } ),
( 'u7107', { 'bipartite' : 'users' } ),
( 'u1649', { 'bipartite' : 'users' } ),
( 'u2182', { 'bipartite' : 'users' } ),
( 'u592', { 'bipartite' : 'users' } ),
( 'u84', { 'bipartite' : 'users' } ),
( 'u3421', { 'bipartite' : 'users' } ),
( 'u7204', { 'bipartite' : 'users' } ),
( 'u4760', { 'bipartite' : 'users' } ),
( 'u1573', { 'bipartite' : 'users' } ),
( 'u206', { 'bipartite' : 'users' } ),
( 'u3074', { 'bipartite' : 'users' } ),
( 'u8333', { 'bipartite' : 'users' } ),
( 'u1141', { 'bipartite' : 'users' } ),
( 'u7252', { 'bipartite' : 'users' } ),
( 'u3879', { 'bipartite' : 'users' } ),
( 'u9191', { 'bipartite' : 'users' } ),
( 'u2460', { 'bipartite' : 'users' } ),
( 'u8219', { 'bipartite' : 'users' } ),
( 'u4161', { 'bipartite' : 'users' } ),
( 'u6436', { 'bipartite' : 'users' } ),
( 'u4645', { 'bipartite' : 'users' } ),
( 'u9341', { 'bipartite' : 'users' } ),
( 'u8609', { 'bipartite' : 'users' } ),
( 'u973', { 'bipartite' : 'users' } ),
( 'u3902', { 'bipartite' : 'users' } ),
( 'u8603', { 'bipartite' : 'users' } ),
( 'u7164', { 'bipartite' : 'users' } ),
( 'u2335', { 'bipartite' : 'users' } ),
( 'u30', { 'bipartite' : 'users' } ),
( 'u2675', { 'bipartite' : 'users' } ),
( 'u913', { 'bipartite' : 'users' } ),
( 'u6777', { 'bipartite' : 'users' } ),
( 'u1757', { 'bipartite' : 'users' } ),
( 'u3604', { 'bipartite' : 'users' } ),
( 'u3283', { 'bipartite' : 'users' } ),
( 'u6854', { 'bipartite' : 'users' } ),
( 'u5907', { 'bipartite' : 'users' } ),
( 'u6004', { 'bipartite' : 'users' } ),
( 'u2545', { 'bipartite' : 'users' } ),
( 'u74', { 'bipartite' : 'users' } ),
( 'u6495', { 'bipartite' : 'users' } ),
( 'u9614', { 'bipartite' : 'users' } ),
( 'u1538', { 'bipartite' : 'users' } ),
( 'u2945', { 'bipartite' : 'users' } ),
( 'u7073', { 'bipartite' : 'users' } ),
( 'u1665', { 'bipartite' : 'users' } ),
( 'u2530', { 'bipartite' : 'users' } ),
( 'u10918', { 'bipartite' : 'users' } ),
( 'u8297', { 'bipartite' : 'users' } ),
( 'u2513', { 'bipartite' : 'users' } ),
( 'u1153', { 'bipartite' : 'users' } ),
( 'u3344', { 'bipartite' : 'users' } ),
( 'u8705', { 'bipartite' : 'users' } ),
( 'u10513', { 'bipartite' : 'users' } ),
( 'u6914', { 'bipartite' : 'users' } ),
( 'u386', { 'bipartite' : 'users' } ),
( 'u1231', { 'bipartite' : 'users' } ),
( 'u5340', { 'bipartite' : 'users' } ),
( 'u645', { 'bipartite' : 'users' } ),
( 'u9483', { 'bipartite' : 'users' } ),
( 'u3217', { 'bipartite' : 'users' } ),
( 'u247', { 'bipartite' : 'users' } ),
( 'u7591', { 'bipartite' : 'users' } ),
( 'u5055', { 'bipartite' : 'users' } ),
( 'u2006', { 'bipartite' : 'users' } ),
( 'u3687', { 'bipartite' : 'users' } ),
( 'u1039', { 'bipartite' : 'users' } ),
( 'u3209', { 'bipartite' : 'users' } ),
( 'u9126', { 'bipartite' : 'users' } ),
( 'u5624', { 'bipartite' : 'users' } ),
( 'u2733', { 'bipartite' : 'users' } ),
( 'u3006', { 'bipartite' : 'users' } ),
( 'u1075', { 'bipartite' : 'users' } ),
( 'u1313', { 'bipartite' : 'users' } ),
( 'u3174', { 'bipartite' : 'users' } ),
( 'u6902', { 'bipartite' : 'users' } ),
( 'u4065', { 'bipartite' : 'users' } ),
( 'u9045', { 'bipartite' : 'users' } ),
( 'u10785', { 'bipartite' : 'users' } ),
( 'u7285', { 'bipartite' : 'users' } ),
( 'u10923', { 'bipartite' : 'users' } ),
( 'u4896', { 'bipartite' : 'users' } ),
( 'u10431', { 'bipartite' : 'users' } ),
( 'u6876', { 'bipartite' : 'users' } ),
( 'u3161', { 'bipartite' : 'users' } ),
( 'u414', { 'bipartite' : 'users' } ),
( 'u2090', { 'bipartite' : 'users' } ),
( 'u9173', { 'bipartite' : 'users' } ),
( 'u8557', { 'bipartite' : 'users' } ),
( 'u256', { 'bipartite' : 'users' } ),
( 'u268', { 'bipartite' : 'users' } ),
( 'u4963', { 'bipartite' : 'users' } ),
( 'u2854', { 'bipartite' : 'users' } ),
( 'u409', { 'bipartite' : 'users' } ),
( 'u703', { 'bipartite' : 'users' } ),
( 'u2284', { 'bipartite' : 'users' } ),
( 'u2522', { 'bipartite' : 'users' } ),
( 'u3142', { 'bipartite' : 'users' } ),
( 'u6172', { 'bipartite' : 'users' } ),
( 'u1069', { 'bipartite' : 'users' } ),
( 'u6651', { 'bipartite' : 'users' } ),
( 'u9724', { 'bipartite' : 'users' } ),
( 'u1481', { 'bipartite' : 'users' } ),
( 'u6985', { 'bipartite' : 'users' } ),
( 'u2947', { 'bipartite' : 'users' } ),
( 'u8826', { 'bipartite' : 'users' } ),
( 'u2735', { 'bipartite' : 'users' } ),
( 'u301', { 'bipartite' : 'users' } ),
( 'u4439', { 'bipartite' : 'users' } ),
( 'u9738', { 'bipartite' : 'users' } ),
( 'u604', { 'bipartite' : 'users' } ),
( 'u1627', { 'bipartite' : 'users' } ),
( 'u723', { 'bipartite' : 'users' } ),
( 'u1113', { 'bipartite' : 'users' } ),
( 'u742', { 'bipartite' : 'users' } ),
( 'u4220', { 'bipartite' : 'users' } ),
( 'u2422', { 'bipartite' : 'users' } ),
( 'u978', { 'bipartite' : 'users' } ),
( 'u2771', { 'bipartite' : 'users' } ),
( 'u2087', { 'bipartite' : 'users' } ),
( 'u3313', { 'bipartite' : 'users' } ),
( 'u1171', { 'bipartite' : 'users' } ),
( 'u1254', { 'bipartite' : 'users' } ),
( 'u921', { 'bipartite' : 'users' } ),
( 'u793', { 'bipartite' : 'users' } ),
( 'u764', { 'bipartite' : 'users' } ),
( 'u4796', { 'bipartite' : 'users' } ),
( 'u7922', { 'bipartite' : 'users' } ),
( 'u2074', { 'bipartite' : 'users' } ),
( 'u10057', { 'bipartite' : 'users' } ),
( 'u1208', { 'bipartite' : 'users' } ),
( 'u1458', { 'bipartite' : 'users' } ),
( 'u1781', { 'bipartite' : 'users' } ),
( 'u9399', { 'bipartite' : 'users' } ),
( 'u1207', { 'bipartite' : 'users' } ),
( 'u2166', { 'bipartite' : 'users' } ),
( 'u9387', { 'bipartite' : 'users' } ),
( 'u3316', { 'bipartite' : 'users' } ),
( 'u2068', { 'bipartite' : 'users' } ),
( 'u4976', { 'bipartite' : 'users' } ),
( 'u3877', { 'bipartite' : 'users' } ),
( 'u298', { 'bipartite' : 'users' } ),
( 'u589', { 'bipartite' : 'users' } ),
( 'u8641', { 'bipartite' : 'users' } ),
( 'u1815', { 'bipartite' : 'users' } ),
( 'u6093', { 'bipartite' : 'users' } ),
( 'u7861', { 'bipartite' : 'users' } ),
( 'u10459', { 'bipartite' : 'users' } ),
( 'u3848', { 'bipartite' : 'users' } ),
( 'u824', { 'bipartite' : 'users' } ),
( 'u6037', { 'bipartite' : 'users' } ),
( 'u2368', { 'bipartite' : 'users' } ),
( 'u1419', { 'bipartite' : 'users' } ),
( 'u1248', { 'bipartite' : 'users' } ),
( 'u361', { 'bipartite' : 'users' } ),
( 'u1012', { 'bipartite' : 'users' } ),
( 'u1645', { 'bipartite' : 'users' } ),
( 'u698', { 'bipartite' : 'users' } ),
( 'u8495', { 'bipartite' : 'users' } ),
( 'u4014', { 'bipartite' : 'users' } ),
( 'u9420', { 'bipartite' : 'users' } ),
( 'u4552', { 'bipartite' : 'users' } ),
( 'u1691', { 'bipartite' : 'users' } ),
( 'u1779', { 'bipartite' : 'users' } ),
( 'u7527', { 'bipartite' : 'users' } ),
( 'u3237', { 'bipartite' : 'users' } ),
( 'u765', { 'bipartite' : 'users' } ),
( 'u1662', { 'bipartite' : 'users' } ),
( 'u1697', { 'bipartite' : 'users' } ),
( 'u1159', { 'bipartite' : 'users' } ),
( 'u5456', { 'bipartite' : 'users' } ),
( 'u2516', { 'bipartite' : 'users' } ),
( 'u7455', { 'bipartite' : 'users' } ),
( 'u10180', { 'bipartite' : 'users' } ),
( 'u402', { 'bipartite' : 'users' } ),
( 'u1898', { 'bipartite' : 'users' } ),
( 'u7649', { 'bipartite' : 'users' } ),
( 'u10684', { 'bipartite' : 'users' } ),
( 'u8445', { 'bipartite' : 'users' } ),
( 'u6456', { 'bipartite' : 'users' } ),
( 'u4046', { 'bipartite' : 'users' } ),
( 'u1947', { 'bipartite' : 'users' } ),
( 'u7785', { 'bipartite' : 'users' } ),
( 'u1629', { 'bipartite' : 'users' } ),
( 'u934', { 'bipartite' : 'users' } ),
( 'u3360', { 'bipartite' : 'users' } ),
( 'u10618', { 'bipartite' : 'users' } ),
( 'u627', { 'bipartite' : 'users' } ),
( 'u2173', { 'bipartite' : 'users' } ),
( 'u9705', { 'bipartite' : 'users' } ),
( 'u3110', { 'bipartite' : 'users' } ),
( 'u7456', { 'bipartite' : 'users' } ),
( 'u10704', { 'bipartite' : 'users' } ),
( 'u9915', { 'bipartite' : 'users' } ),
( 'u10745', { 'bipartite' : 'users' } ),
( 'u633', { 'bipartite' : 'users' } ),
( 'u7483', { 'bipartite' : 'users' } ),
( 'u2243', { 'bipartite' : 'users' } ),
( 'u2208', { 'bipartite' : 'users' } ),
( 'u157', { 'bipartite' : 'users' } ),
( 'u942', { 'bipartite' : 'users' } ),
( 'u9781', { 'bipartite' : 'users' } ),
( 'u637', { 'bipartite' : 'users' } ),
( 'u41', { 'bipartite' : 'users' } ),
( 'u1180', { 'bipartite' : 'users' } ),
( 'u356', { 'bipartite' : 'users' } ),
( 'u5350', { 'bipartite' : 'users' } ),
( 'u3492', { 'bipartite' : 'users' } ),
( 'u4939', { 'bipartite' : 'users' } ),
( 'u9329', { 'bipartite' : 'users' } ),
( 'u524', { 'bipartite' : 'users' } ),
( 'u4675', { 'bipartite' : 'users' } ),
( 'u10685', { 'bipartite' : 'users' } ),
( 'u215', { 'bipartite' : 'users' } ),
( 'u396', { 'bipartite' : 'users' } ),
( 'u1666', { 'bipartite' : 'users' } ),
( 'u7877', { 'bipartite' : 'users' } ),
( 'u6653', { 'bipartite' : 'users' } ),
( 'u9790', { 'bipartite' : 'users' } ),
( 'u872', { 'bipartite' : 'users' } ),
( 'u1516', { 'bipartite' : 'users' } ),
( 'u3599', { 'bipartite' : 'users' } ),
( 'u8461', { 'bipartite' : 'users' } ),
( 'u7587', { 'bipartite' : 'users' } ),
( 'u5609', { 'bipartite' : 'users' } ),
( 'u10348', { 'bipartite' : 'users' } ),
( 'u9662', { 'bipartite' : 'users' } ),
( 'u6128', { 'bipartite' : 'users' } ),
( 'u10360', { 'bipartite' : 'users' } ),
( 'u4323', { 'bipartite' : 'users' } ),
( 'u2632', { 'bipartite' : 'users' } ),
( 'u1336', { 'bipartite' : 'users' } ),
( 'u115', { 'bipartite' : 'users' } ),
( 'u6691', { 'bipartite' : 'users' } ),
( 'u8024', { 'bipartite' : 'users' } ),
( 'u91', { 'bipartite' : 'users' } ),
( 'u4430', { 'bipartite' : 'users' } ),
( 'u1320', { 'bipartite' : 'users' } ),
( 'u2275', { 'bipartite' : 'users' } ),
( 'u1', { 'bipartite' : 'users' } ),
( 'u6322', { 'bipartite' : 'users' } ),
( 'u3577', { 'bipartite' : 'users' } ),
( 'u2929', { 'bipartite' : 'users' } ),
( 'u8060', { 'bipartite' : 'users' } ),
( 'u1805', { 'bipartite' : 'users' } ),
( 'u7737', { 'bipartite' : 'users' } ),
( 'u2317', { 'bipartite' : 'users' } ),
( 'u4280', { 'bipartite' : 'users' } ),
( 'u2802', { 'bipartite' : 'users' } ),
( 'u1782', { 'bipartite' : 'users' } ),
( 'u1296', { 'bipartite' : 'users' } ),
( 'u673', { 'bipartite' : 'users' } ),
( 'u2848', { 'bipartite' : 'users' } ),
( 'u5676', { 'bipartite' : 'users' } ),
( 'u10913', { 'bipartite' : 'users' } ),
( 'u3703', { 'bipartite' : 'users' } ),
( 'u7679', { 'bipartite' : 'users' } ),
( 'u9890', { 'bipartite' : 'users' } ),
( 'u2311', { 'bipartite' : 'users' } ),
( 'u2937', { 'bipartite' : 'users' } ),
( 'u741', { 'bipartite' : 'users' } ),
( 'u10868', { 'bipartite' : 'users' } ),
( 'u5918', { 'bipartite' : 'users' } ),
( 'u4647', { 'bipartite' : 'users' } ),
( 'u10245', { 'bipartite' : 'users' } ),
( 'u4974', { 'bipartite' : 'users' } ),
( 'u1856', { 'bipartite' : 'users' } ),
( 'u3645', { 'bipartite' : 'users' } ),
( 'u4665', { 'bipartite' : 'users' } ),
( 'u2106', { 'bipartite' : 'users' } ),
( 'u2339', { 'bipartite' : 'users' } ),
( 'u10638', { 'bipartite' : 'users' } ),
( 'u7685', { 'bipartite' : 'users' } ),
( 'u7619', { 'bipartite' : 'users' } ),
( 'u1409', { 'bipartite' : 'users' } ),
( 'u54', { 'bipartite' : 'users' } ),
( 'u5698', { 'bipartite' : 'users' } ),
( 'u4334', { 'bipartite' : 'users' } ),
( 'u1514', { 'bipartite' : 'users' } ),
( 'u2578', { 'bipartite' : 'users' } ),
( 'u6080', { 'bipartite' : 'users' } ),
( 'u10757', { 'bipartite' : 'users' } ),
( 'u1002', { 'bipartite' : 'users' } ),
( 'u3563', { 'bipartite' : 'users' } ),
( 'u5897', { 'bipartite' : 'users' } ),
( 'u7303', { 'bipartite' : 'users' } ),
( 'u4214', { 'bipartite' : 'users' } ),
( 'u1739', { 'bipartite' : 'users' } ),
( 'u479', { 'bipartite' : 'users' } ),
( 'u1188', { 'bipartite' : 'users' } ),
( 'u308', { 'bipartite' : 'users' } ),
( 'u1324', { 'bipartite' : 'users' } ),
( 'u3795', { 'bipartite' : 'users' } ),
( 'u9256', { 'bipartite' : 'users' } ),
( 'u4462', { 'bipartite' : 'users' } ),
( 'u1311', { 'bipartite' : 'users' } ),
( 'u142', { 'bipartite' : 'users' } ),
( 'u7239', { 'bipartite' : 'users' } ),
( 'u6106', { 'bipartite' : 'users' } ),
( 'u52', { 'bipartite' : 'users' } ),
( 'u3858', { 'bipartite' : 'users' } ),
( 'u1081', { 'bipartite' : 'users' } ),
( 'u6957', { 'bipartite' : 'users' } ),
( 'u2136', { 'bipartite' : 'users' } ),
( 'u483', { 'bipartite' : 'users' } ),
( 'u2984', { 'bipartite' : 'users' } ),
( 'u6209', { 'bipartite' : 'users' } ),
( 'u211', { 'bipartite' : 'users' } ),
( 'u6162', { 'bipartite' : 'users' } ),
( 'u322', { 'bipartite' : 'users' } ),
( 'u7782', { 'bipartite' : 'users' } ),
( 'u8657', { 'bipartite' : 'users' } ),
( 'u5630', { 'bipartite' : 'users' } ),
( 'u655', { 'bipartite' : 'users' } ),
( 'u5593', { 'bipartite' : 'users' } ),
( 'u2879', { 'bipartite' : 'users' } ),
( 'u5467', { 'bipartite' : 'users' } ),
( 'u8637', { 'bipartite' : 'users' } ),
( 'u6094', { 'bipartite' : 'users' } ),
( 'u4501', { 'bipartite' : 'users' } ),
( 'u2084', { 'bipartite' : 'users' } ),
( 'u4546', { 'bipartite' : 'users' } ),
( 'u2165', { 'bipartite' : 'users' } ),
( 'u2381', { 'bipartite' : 'users' } ),
( 'u9657', { 'bipartite' : 'users' } ),
( 'u8969', { 'bipartite' : 'users' } ),
( 'u116', { 'bipartite' : 'users' } ),
( 'u845', { 'bipartite' : 'users' } ),
( 'u576', { 'bipartite' : 'users' } ),
( 'u155', { 'bipartite' : 'users' } ),
( 'u2274', { 'bipartite' : 'users' } ),
( 'u534', { 'bipartite' : 'users' } ),
( 'u7881', { 'bipartite' : 'users' } ),
( 'u4498', { 'bipartite' : 'users' } ),
( 'u4817', { 'bipartite' : 'users' } ),
( 'u2279', { 'bipartite' : 'users' } ),
( 'u1482', { 'bipartite' : 'users' } ),
( 'u976', { 'bipartite' : 'users' } ),
( 'u6183', { 'bipartite' : 'users' } ),
( 'u3269', { 'bipartite' : 'users' } ),
( 'u3429', { 'bipartite' : 'users' } ),
( 'u2270', { 'bipartite' : 'users' } ),
( 'u2447', { 'bipartite' : 'users' } ),
( 'u3862', { 'bipartite' : 'users' } ),
( 'u2175', { 'bipartite' : 'users' } ),
( 'u366', { 'bipartite' : 'users' } ),
( 'u5790', { 'bipartite' : 'users' } ),
( 'u2008', { 'bipartite' : 'users' } ),
( 'u944', { 'bipartite' : 'users' } ),
( 'u1116', { 'bipartite' : 'users' } ),
( 'u9124', { 'bipartite' : 'users' } ),
( 'u4042', { 'bipartite' : 'users' } ),
( 'u3082', { 'bipartite' : 'users' } ),
( 'u10961', { 'bipartite' : 'users' } ),
( 'u9743', { 'bipartite' : 'users' } ),
( 'u4010', { 'bipartite' : 'users' } ),
( 'u5285', { 'bipartite' : 'users' } ),
( 'u544', { 'bipartite' : 'users' } ),
( 'u6926', { 'bipartite' : 'users' } ),
( 'u2388', { 'bipartite' : 'users' } ),
( 'u10341', { 'bipartite' : 'users' } ),
( 'u6170', { 'bipartite' : 'users' } ),
( 'u1927', { 'bipartite' : 'users' } ),
( 'u6494', { 'bipartite' : 'users' } ),
( 'u5709', { 'bipartite' : 'users' } ),
( 'u6421', { 'bipartite' : 'users' } ),
( 'u6776', { 'bipartite' : 'users' } ),
( 'u3544', { 'bipartite' : 'users' } ),
( 'u10960', { 'bipartite' : 'users' } ),
( 'u5093', { 'bipartite' : 'users' } ),
( 'u1814', { 'bipartite' : 'users' } ),
( 'u3337', { 'bipartite' : 'users' } ),
( 'u5397', { 'bipartite' : 'users' } ),
( 'u7557', { 'bipartite' : 'users' } ),
( 'u6300', { 'bipartite' : 'users' } ),
( 'u1350', { 'bipartite' : 'users' } ),
( 'u4927', { 'bipartite' : 'users' } ),
( 'u4378', { 'bipartite' : 'users' } ),
( 'u1986', { 'bipartite' : 'users' } ),
( 'u739', { 'bipartite' : 'users' } ),
( 'u4236', { 'bipartite' : 'users' } ),
( 'u4382', { 'bipartite' : 'users' } ),
( 'u3315', { 'bipartite' : 'users' } ),
( 'u3231', { 'bipartite' : 'users' } ),
( 'u796', { 'bipartite' : 'users' } ),
( 'u4970', { 'bipartite' : 'users' } ),
( 'u646', { 'bipartite' : 'users' } ),
( 'u10006', { 'bipartite' : 'users' } ),
( 'u6244', { 'bipartite' : 'users' } ),
( 'u2359', { 'bipartite' : 'users' } ),
( 'u446', { 'bipartite' : 'users' } ),
( 'u5644', { 'bipartite' : 'users' } ),
( 'u797', { 'bipartite' : 'users' } ),
( 'u1513', { 'bipartite' : 'users' } ),
( 'u924', { 'bipartite' : 'users' } ),
( 'u499', { 'bipartite' : 'users' } ),
( 'u2598', { 'bipartite' : 'users' } ),
( 'u837', { 'bipartite' : 'users' } ),
( 'u248', { 'bipartite' : 'users' } ),
( 'u371', { 'bipartite' : 'users' } ),
( 'u737', { 'bipartite' : 'users' } ),
( 'u2213', { 'bipartite' : 'users' } ),
( 'u5138', { 'bipartite' : 'users' } ),
( 'u15', { 'bipartite' : 'users' } ),
( 'u1067', { 'bipartite' : 'users' } ),
( 'u9267', { 'bipartite' : 'users' } ),
( 'u6690', { 'bipartite' : 'users' } ),
( 'u7076', { 'bipartite' : 'users' } ),
( 'u7667', { 'bipartite' : 'users' } ),
( 'u1054', { 'bipartite' : 'users' } ),
( 'u1941', { 'bipartite' : 'users' } ),
( 'u227', { 'bipartite' : 'users' } ),
( 'u8355', { 'bipartite' : 'users' } ),
( 'u5244', { 'bipartite' : 'users' } ),
( 'u5681', { 'bipartite' : 'users' } ),
( 'u5085', { 'bipartite' : 'users' } ),
( 'u516', { 'bipartite' : 'users' } ),
( 'u6754', { 'bipartite' : 'users' } ),
( 'u2429', { 'bipartite' : 'users' } ),
( 'u3345', { 'bipartite' : 'users' } ),
( 'u4075', { 'bipartite' : 'users' } ),
( 'u907', { 'bipartite' : 'users' } ),
( 'u8939', { 'bipartite' : 'users' } ),
( 'u1057', { 'bipartite' : 'users' } ),
( 'u3844', { 'bipartite' : 'users' } ),
( 'u10616', { 'bipartite' : 'users' } ),
( 'u5359', { 'bipartite' : 'users' } ),
( 'u972', { 'bipartite' : 'users' } ),
( 'u8504', { 'bipartite' : 'users' } ),
( 'u7392', { 'bipartite' : 'users' } ),
( 'u1850', { 'bipartite' : 'users' } ),
( 'u10002', { 'bipartite' : 'users' } ),
( 'u2171', { 'bipartite' : 'users' } ),
( 'u3449', { 'bipartite' : 'users' } ),
( 'u10340', { 'bipartite' : 'users' } ),
( 'u10778', { 'bipartite' : 'users' } ),
( 'u1416', { 'bipartite' : 'users' } ),
( 'u5741', { 'bipartite' : 'users' } ),
( 'u3939', { 'bipartite' : 'users' } ),
( 'u6341', { 'bipartite' : 'users' } ),
( 'u1959', { 'bipartite' : 'users' } ),
( 'u4788', { 'bipartite' : 'users' } ),
( 'u8351', { 'bipartite' : 'users' } ),
( 'u9855', { 'bipartite' : 'users' } ),
( 'u8845', { 'bipartite' : 'users' } ),
( 'u5778', { 'bipartite' : 'users' } ),
( 'u1122', { 'bipartite' : 'users' } ),
( 'u9615', { 'bipartite' : 'users' } ),
( 'u2832', { 'bipartite' : 'users' } ),
( 'u1124', { 'bipartite' : 'users' } ),
( 'u325', { 'bipartite' : 'users' } ),
( 'u2445', { 'bipartite' : 'users' } ),
( 'u1374', { 'bipartite' : 'users' } ),
( 'u6833', { 'bipartite' : 'users' } ),
( 'u6266', { 'bipartite' : 'users' } ),
( 'u8776', { 'bipartite' : 'users' } ),
( 'u6785', { 'bipartite' : 'users' } ),
( 'u2884', { 'bipartite' : 'users' } ),
( 'u9043', { 'bipartite' : 'users' } ),
( 'u6415', { 'bipartite' : 'users' } ),
( 'u3918', { 'bipartite' : 'users' } ),
( 'u6618', { 'bipartite' : 'users' } ),
( 'u10409', { 'bipartite' : 'users' } ),
( 'u5033', { 'bipartite' : 'users' } ),
( 'u4057', { 'bipartite' : 'users' } ),
( 'u5256', { 'bipartite' : 'users' } ),
( 'u4401', { 'bipartite' : 'users' } ),
( 'u4313', { 'bipartite' : 'users' } ),
( 'u6234', { 'bipartite' : 'users' } ),
( 'u7876', { 'bipartite' : 'users' } ),
( 'u83', { 'bipartite' : 'users' } ),
( 'u6164', { 'bipartite' : 'users' } ),
( 'u1135', { 'bipartite' : 'users' } ),
( 'u7349', { 'bipartite' : 'users' } ),
( 'u6219', { 'bipartite' : 'users' } ),
( 'u1385', { 'bipartite' : 'users' } ),
( 'u784', { 'bipartite' : 'users' } ),
( 'u96', { 'bipartite' : 'users' } ),
( 'u3305', { 'bipartite' : 'users' } ),
( 'u8303', { 'bipartite' : 'users' } ),
( 'u1539', { 'bipartite' : 'users' } ),
( 'u1438', { 'bipartite' : 'users' } ),
( 'u3187', { 'bipartite' : 'users' } ),
( 'u947', { 'bipartite' : 'users' } ),
( 'u3504', { 'bipartite' : 'users' } ),
( 'u9293', { 'bipartite' : 'users' } ),
( 'u8677', { 'bipartite' : 'users' } ),
( 'u1679', { 'bipartite' : 'users' } ),
( 'u6007', { 'bipartite' : 'users' } ),
( 'u7893', { 'bipartite' : 'users' } ),
( 'u3228', { 'bipartite' : 'users' } ),
( 'u1887', { 'bipartite' : 'users' } ),
( 'u1656', { 'bipartite' : 'users' } ),
( 'u8420', { 'bipartite' : 'users' } ),
( 'u3254', { 'bipartite' : 'users' } ),
( 'u7829', { 'bipartite' : 'users' } ),
( 'u5089', { 'bipartite' : 'users' } ),
( 'u7962', { 'bipartite' : 'users' } ),
( 'u8023', { 'bipartite' : 'users' } ),
( 'u3992', { 'bipartite' : 'users' } ),
( 'u2931', { 'bipartite' : 'users' } ),
( 'u89', { 'bipartite' : 'users' } ),
( 'u1031', { 'bipartite' : 'users' } ),
( 'u6488', { 'bipartite' : 'users' } ),
( 'u6817', { 'bipartite' : 'users' } ),
( 'u1264', { 'bipartite' : 'users' } ),
( 'u8272', { 'bipartite' : 'users' } ),
( 'u6381', { 'bipartite' : 'users' } ),
( 'u1151', { 'bipartite' : 'users' } ),
( 'u7337', { 'bipartite' : 'users' } ),
( 'u3404', { 'bipartite' : 'users' } ),
( 'u1659', { 'bipartite' : 'users' } ),
( 'u3929', { 'bipartite' : 'users' } ),
( 'u1774', { 'bipartite' : 'users' } ),
( 'u6305', { 'bipartite' : 'users' } ),
( 'u922', { 'bipartite' : 'users' } ),
( 'u5124', { 'bipartite' : 'users' } ),
( 'u3993', { 'bipartite' : 'users' } ),
( 'u10713', { 'bipartite' : 'users' } ),
( 'u422', { 'bipartite' : 'users' } ),
( 'u9744', { 'bipartite' : 'users' } ),
( 'u7360', { 'bipartite' : 'users' } ),
( 'u6676', { 'bipartite' : 'users' } ),
( 'u4263', { 'bipartite' : 'users' } ),
( 'u1933', { 'bipartite' : 'users' } ),
( 'u4495', { 'bipartite' : 'users' } ),
( 'u997', { 'bipartite' : 'users' } ),
( 'u3075', { 'bipartite' : 'users' } ),
( 'u7862', { 'bipartite' : 'users' } ),
( 'u7546', { 'bipartite' : 'users' } ),
( 'u1103', { 'bipartite' : 'users' } ),
( 'u1118', { 'bipartite' : 'users' } ),
( 'u10392', { 'bipartite' : 'users' } ),
( 'u2736', { 'bipartite' : 'users' } ),
( 'u135', { 'bipartite' : 'users' } ),
( 'u3700', { 'bipartite' : 'users' } ),
( 'u8743', { 'bipartite' : 'users' } ),
( 'u5461', { 'bipartite' : 'users' } ),
( 'u787', { 'bipartite' : 'users' } ),
( 'u574', { 'bipartite' : 'users' } ),
( 'u8132', { 'bipartite' : 'users' } ),
( 'u7063', { 'bipartite' : 'users' } ),
( 'u3597', { 'bipartite' : 'users' } ),
( 'u208', { 'bipartite' : 'users' } ),
( 'u862', { 'bipartite' : 'users' } ),
( 'u134', { 'bipartite' : 'users' } ),
( 'u4463', { 'bipartite' : 'users' } ),
( 'u1577', { 'bipartite' : 'users' } ),
( 'u7800', { 'bipartite' : 'users' } ),
( 'u64', { 'bipartite' : 'users' } ),
( 'u505', { 'bipartite' : 'users' } ),
( 'u2160', { 'bipartite' : 'users' } ),
( 'u376', { 'bipartite' : 'users' } ),
( 'u10851', { 'bipartite' : 'users' } ),
( 'u2812', { 'bipartite' : 'users' } ),
( 'u5318', { 'bipartite' : 'users' } ),
( 'u5044', { 'bipartite' : 'users' } ),
( 'u4740', { 'bipartite' : 'users' } ),
( 'u1910', { 'bipartite' : 'users' } ),
( 'u4373', { 'bipartite' : 'users' } ),
( 'u2955', { 'bipartite' : 'users' } ),
( 'u6761', { 'bipartite' : 'users' } ),
( 'u6758', { 'bipartite' : 'users' } ),
( 'u2092', { 'bipartite' : 'users' } ),
( 'u1345', { 'bipartite' : 'users' } ),
( 'u10083', { 'bipartite' : 'users' } ),
( 'u7544', { 'bipartite' : 'users' } ),
( 'u10632', { 'bipartite' : 'users' } ),
( 'u7148', { 'bipartite' : 'users' } ),
( 'u10821', { 'bipartite' : 'users' } ),
( 'u664', { 'bipartite' : 'users' } ),
( 'u2606', { 'bipartite' : 'users' } ),
( 'u7588', { 'bipartite' : 'users' } ),
( 'u1673', { 'bipartite' : 'users' } ),
( 'u284', { 'bipartite' : 'users' } ),
( 'u5473', { 'bipartite' : 'users' } ),
( 'u8655', { 'bipartite' : 'users' } ),
( 'u2224', { 'bipartite' : 'users' } ),
( 'u3649', { 'bipartite' : 'users' } ),
( 'u533', { 'bipartite' : 'users' } ),
( 'u3045', { 'bipartite' : 'users' } ),
( 'u1145', { 'bipartite' : 'users' } ),
( 'u3089', { 'bipartite' : 'users' } ),
( 'u3912', { 'bipartite' : 'users' } ),
( 'u2312', { 'bipartite' : 'users' } ),
( 'u6413', { 'bipartite' : 'users' } ),
( 'u198', { 'bipartite' : 'users' } ),
( 'u696', { 'bipartite' : 'users' } ),
( 'u9060', { 'bipartite' : 'users' } ),
( 'u10827', { 'bipartite' : 'users' } ),
( 'u332', { 'bipartite' : 'users' } ),
( 'u2046', { 'bipartite' : 'users' } ),
( 'u8487', { 'bipartite' : 'users' } ),
( 'u1318', { 'bipartite' : 'users' } ),
( 'u2630', { 'bipartite' : 'users' } ),
( 'u1549', { 'bipartite' : 'users' } ),
( 'u1391', { 'bipartite' : 'users' } ),
( 'u1485', { 'bipartite' : 'users' } ),
( 'u1194', { 'bipartite' : 'users' } ),
( 'u7333', { 'bipartite' : 'users' } ),
( 'u6016', { 'bipartite' : 'users' } ),
( 'u8601', { 'bipartite' : 'users' } ),
( 'u2169', { 'bipartite' : 'users' } ),
( 'u1204', { 'bipartite' : 'users' } ),
( 'u1422', { 'bipartite' : 'users' } ),
( 'u5411', { 'bipartite' : 'users' } ),
( 'u1844', { 'bipartite' : 'users' } ),
( 'u1623', { 'bipartite' : 'users' } ),
( 'u7642', { 'bipartite' : 'users' } ),
( 'u5610', { 'bipartite' : 'users' } ),
( 'u1121', { 'bipartite' : 'users' } ),
( 'u5563', { 'bipartite' : 'users' } ),
( 'u5273', { 'bipartite' : 'users' } ),
( 'u2476', { 'bipartite' : 'users' } ),
( 'u4734', { 'bipartite' : 'users' } ),
( 'u4512', { 'bipartite' : 'users' } ),
( 'u437', { 'bipartite' : 'users' } ),
( 'u10476', { 'bipartite' : 'users' } ),
( 'u5899', { 'bipartite' : 'users' } ),
( 'u55', { 'bipartite' : 'users' } ),
( 'u4513', { 'bipartite' : 'users' } ),
( 'u4904', { 'bipartite' : 'users' } ),
( 'u5084', { 'bipartite' : 'users' } ),
( 'u1405', { 'bipartite' : 'users' } ),
( 'u100', { 'bipartite' : 'users' } ),
( 'u9357', { 'bipartite' : 'users' } ),
( 'u195', { 'bipartite' : 'users' } ),
( 'u8664', { 'bipartite' : 'users' } ),
( 'u1731', { 'bipartite' : 'users' } ),
( 'u711', { 'bipartite' : 'users' } ),
( 'u279', { 'bipartite' : 'users' } ),
( 'u1243', { 'bipartite' : 'users' } ),
( 'u3498', { 'bipartite' : 'users' } ),
( 'u8775', { 'bipartite' : 'users' } ),
( 'u3080', { 'bipartite' : 'users' } ),
( 'u7126', { 'bipartite' : 'users' } ),
( 'u731', { 'bipartite' : 'users' } ),
( 'u5300', { 'bipartite' : 'users' } ),
( 'u1230', { 'bipartite' : 'users' } ),
( 'u53', { 'bipartite' : 'users' } ),
( 'u4875', { 'bipartite' : 'users' } ),
( 'u1047', { 'bipartite' : 'users' } ),
( 'u1799', { 'bipartite' : 'users' } ),
( 'u8569', { 'bipartite' : 'users' } ),
( 'u4159', { 'bipartite' : 'users' } ),
( 'u3662', { 'bipartite' : 'users' } ),
( 'u5171', { 'bipartite' : 'users' } ),
( 'u220', { 'bipartite' : 'users' } ),
( 'u4946', { 'bipartite' : 'users' } ),
( 'u3851', { 'bipartite' : 'users' } ),
( 'u537', { 'bipartite' : 'users' } ),
( 'u4634', { 'bipartite' : 'users' } ),
( 'u2479', { 'bipartite' : 'users' } ),
( 'u1943', { 'bipartite' : 'users' } ),
( 'u6459', { 'bipartite' : 'users' } ),
( 'u1250', { 'bipartite' : 'users' } ),
( 'u8122', { 'bipartite' : 'users' } ),
( 'u9139', { 'bipartite' : 'users' } ),
( 'u1247', { 'bipartite' : 'users' } ),
( 'u1618', { 'bipartite' : 'users' } ),
( 'u3610', { 'bipartite' : 'users' } ),
( 'u5835', { 'bipartite' : 'users' } ),
( 'u6577', { 'bipartite' : 'users' } ),
( 'u349', { 'bipartite' : 'users' } ),
( 'u1149', { 'bipartite' : 'users' } ),
( 'u8616', { 'bipartite' : 'users' } ),
( 'u3243', { 'bipartite' : 'users' } ),
( 'u2968', { 'bipartite' : 'users' } ),
( 'u8342', { 'bipartite' : 'users' } ),
( 'u1415', { 'bipartite' : 'users' } ),
( 'u9974', { 'bipartite' : 'users' } ),
( 'u4088', { 'bipartite' : 'users' } ),
( 'u2358', { 'bipartite' : 'users' } ),
( 'u5267', { 'bipartite' : 'users' } ),
( 'u3258', { 'bipartite' : 'users' } ),
( 'u7001', { 'bipartite' : 'users' } ),
( 'u4769', { 'bipartite' : 'users' } ),
( 'u3650', { 'bipartite' : 'users' } ),
( 'u336', { 'bipartite' : 'users' } ),
( 'u444', { 'bipartite' : 'users' } ),
( 'u5948', { 'bipartite' : 'users' } ),
( 'u6077', { 'bipartite' : 'users' } ),
( 'u501', { 'bipartite' : 'users' } ),
( 'u326', { 'bipartite' : 'users' } ),
( 'u324', { 'bipartite' : 'users' } ),
( 'u2282', { 'bipartite' : 'users' } ),
( 'u7692', { 'bipartite' : 'users' } ),
( 'u10519', { 'bipartite' : 'users' } ),
( 'u8734', { 'bipartite' : 'users' } ),
( 'u9670', { 'bipartite' : 'users' } ),
( 'u5194', { 'bipartite' : 'users' } ),
( 'u9801', { 'bipartite' : 'users' } ),
( 'u569', { 'bipartite' : 'users' } ),
( 'u6988', { 'bipartite' : 'users' } ),
( 'u4259', { 'bipartite' : 'users' } ),
( 'u667', { 'bipartite' : 'users' } ),
( 'u5625', { 'bipartite' : 'users' } ),
( 'u1876', { 'bipartite' : 'users' } ),
( 'u4207', { 'bipartite' : 'users' } ),
( 'u3040', { 'bipartite' : 'users' } ),
( 'u2410', { 'bipartite' : 'users' } ),
( 'u748', { 'bipartite' : 'users' } ),
( 'u4677', { 'bipartite' : 'users' } ),
( 'u719', { 'bipartite' : 'users' } ),
( 'u5152', { 'bipartite' : 'users' } ),
( 'u40', { 'bipartite' : 'users' } ),
( 'u5994', { 'bipartite' : 'users' } ),
( 'u5943', { 'bipartite' : 'users' } ),
( 'u2404', { 'bipartite' : 'users' } ),
( 'u2120', { 'bipartite' : 'users' } ),
( 'u6207', { 'bipartite' : 'users' } ),
( 'u380', { 'bipartite' : 'users' } ),
( 'u4185', { 'bipartite' : 'users' } ),
( 'u3331', { 'bipartite' : 'users' } ),
( 'u3361', { 'bipartite' : 'users' } ),
( 'u5423', { 'bipartite' : 'users' } ),
( 'u4851', { 'bipartite' : 'users' } ),
( 'u1163', { 'bipartite' : 'users' } ),
( 'u8022', { 'bipartite' : 'users' } ),
( 'u104', { 'bipartite' : 'users' } ),
( 'u5070', { 'bipartite' : 'users' } ),
( 'u10529', { 'bipartite' : 'users' } ),
( 'u2497', { 'bipartite' : 'users' } ),
( 'u3233', { 'bipartite' : 'users' } ),
( 'u5077', { 'bipartite' : 'users' } ),
( 'u16', { 'bipartite' : 'users' } ),
( 'u1797', { 'bipartite' : 'users' } ),
( 'u981', { 'bipartite' : 'users' } ),
( 'u7459', { 'bipartite' : 'users' } ),
( 'u5001', { 'bipartite' : 'users' } ),
( 'u608', { 'bipartite' : 'users' } ),
( 'u5191', { 'bipartite' : 'users' } ),
( 'u9845', { 'bipartite' : 'users' } ),
( 'u6132', { 'bipartite' : 'users' } ),
( 'u8577', { 'bipartite' : 'users' } ),
( 'u2814', { 'bipartite' : 'users' } ),
( 'u4118', { 'bipartite' : 'users' } ),
( 'u2026', { 'bipartite' : 'users' } ),
( 'u2624', { 'bipartite' : 'users' } ),
( 'u6718', { 'bipartite' : 'users' } ),
( 'u405', { 'bipartite' : 'users' } ),
( 'u2863', { 'bipartite' : 'users' } ),
( 'u7014', { 'bipartite' : 'users' } ),
( 'u3319', { 'bipartite' : 'users' } ),
( 'u6155', { 'bipartite' : 'users' } ),
( 'u1183', { 'bipartite' : 'users' } ),
( 'u941', { 'bipartite' : 'users' } )]

# %%
edges = [('u8746', 'u1423'),
 ('u9802', 'u10110'),
 ('u7670', 'u3821'),
 ('u7670', 'u6055'),
 ('u1221', 'u3483'),
 ('u1221', 'u6533'),
 ('u1221', 'u10428'),
 ('u1221', 'u6784'),
 ('u1221', 'u9566'),
 ('u1221', 'u804'),
 ('u1221', 'u5700'),
 ('u1221', 'u3494'),
 ('u1221', 'u2611'),
 ('u1221', 'u726'),
 ('u1221', 'u6201'),
 ('u1221', 'u3907'),
 ('u1221', 'u5162'),
 ('u1221', 'u887'),
 ('u1221', 'u666'),
 ('u1221', 'u2325'),
 ('u1221', 'u87'),
 ('u1221', 'u816'),
 ('u1221', 'u2509'),
 ('u1221', 'u3411'),
 ('u1221', 'u2225'),
 ('u1221', 'u1566'),
 ('u1221', 'u5298'),
 ('u1221', 'u6061'),
 ('u1221', 'u7712'),
 ('u1221', 'u661'),
 ('u1221', 'u10588'),
 ('u1221', 'u2823'),
 ('u1221', 'u8917'),
 ('u1221', 'u3280'),
 ('u1221', 'u4367'),
 ('u1221', 'u2430'),
 ('u1221', 'u4592'),
 ('u1221', 'u1682'),
 ('u7644', 'u2230'),
 ('u7644', 'u2730'),
 ('u7644', 'u1294'),
 ('u7644', 'u4853'),
 ('u7644', 'u3405'),
 ('u7644', 'u133'),
 ('u7644', 'u2263'),
 ('u7644', 'u3989'),
 ('u7644', 'u935'),
 ('u7644', 'u1003'),
 ('u7644', 'u21'),
 ('u7644', 'u8783'),
 ('u7644', 'u6955'),
 ('u7644', 'u8992'),
 ('u7644', 'u4256'),
 ('u7644', 'u1978'),
 ('u7644', 'u1940'),
 ('u7644', 'u8729'),
 ('u7644', 'u5740'),
 ('u7644', 'u368'),
 ('u7644', 'u272'),
 ('u7644', 'u4176'),
 ('u7644', 'u5895'),
 ('u7644', 'u5470'),
 ('u7644', 'u10143'),
 ('u7644', 'u8722'),
 ('u7644', 'u280'),
 ('u7644', 'u8647'),
 ('u7644', 'u621'),
 ('u7644', 'u4593'),
 ('u7644', 'u2583'),
 ('u7644', 'u1045'),
 ('u7644', 'u7251'),
 ('u7644', 'u5040'),
 ('u7644', 'u3274'),
 ('u7644', 'u4071'),
 ('u7644', 'u161'),
 ('u7644', 'u8137'),
 ('u7644', 'u844'),
 ('u7644', 'u3509'),
 ('u7644', 'u4189'),
 ('u7644', 'u340'),
 ('u7644', 'u876'),
 ('u7644', 'u8518'),
 ('u7644', 'u5604'),
 ('u7644', 'u1436'),
 ('u7644', 'u4392'),
 ('u7644', 'u2644'),
 ('u7644', 'u9558'),
 ('u7644', 'u357'),
 ('u7644', 'u88'),
 ('u7644', 'u1259'),
 ('u7644', 'u5731'),
 ('u7644', 'u2056'),
 ('u7644', 'u3415'),
 ('u7644', 'u774'),
 ('u7644', 'u7431'),
 ('u7644', 'u5316'),
 ('u7644', 'u4872'),
 ('u7644', 'u5167'),
 ('u7644', 'u9766'),
 ('u7644', 'u7107'),
 ('u7644', 'u1649'),
 ('u7644', 'u2182'),
 ('u7644', 'u592'),
 ('u7644', 'u84'),
 ('u7644', 'u3421'),
 ('u7549', 'u7204'),
 ('u8709', 'u4760'),
 ('u8709', 'u1573'),
 ('u9571', 'u206'),
 ('u9571', 'u3074'),
 ('u9571', 'u8333'),
 ('u9571', 'u1141'),
 ('u7821', 'u7252'),
 ('u7821', 'u3879'),
 ('u8721', 'u9191'),
 ('u8721', 'u2460'),
 ('u8721', 'u8219'),
 ('u8721', 'u4161'),
 ('u8721', 'u6436'),
 ('u8721', 'u4645'),
 ('u8721', 'u9341'),
 ('u8721', 'u8609'),
 ('u8721', 'u973'),
 ('u8721', 'u3902'),
 ('u8721', 'u844'),
 ('u8721', 'u8603'),
 ('u8721', 'u7164'),
 ('u8721', 'u2335'),
 ('u8721', 'u30'),
 ('u8721', 'u2675'),
 ('u7326', 'u913'),
 ('u7326', 'u6777'),
 ('u7326', 'u1757'),
 ('u7326', 'u3604'),
 ('u7326', 'u3283'),
 ('u7326', 'u6854'),
 ('u7326', 'u5907'),
 ('u7326', 'u6004'),
 ('u7326', 'u2545'),
 ('u7326', 'u74'),
 ('u7326', 'u6495'),
 ('u7326', 'u9614'),
 ('u7326', 'u1538'),
 ('u7326', 'u2945'),
 ('u7326', 'u7073'),
 ('u7326', 'u1665'),
 ('u7326', 'u2530'),
 ('u7326', 'u10918'),
 ('u7326', 'u8297'),
 ('u7326', 'u2513'),
 ('u2737', 'u1153'),
 ('u2737', 'u3344'),
 ('u2737', 'u8705'),
 ('u2737', 'u10513'),
 ('u2737', 'u6914'),
 ('u2737', 'u386'),
 ('u2737', 'u1231'),
 ('u2737', 'u5340'),
 ('u2737', 'u645'),
 ('u2737', 'u9483'),
 ('u2737', 'u3217'),
 ('u2737', 'u247'),
 ('u2737', 'u7591'),
 ('u2737', 'u5055'),
 ('u2737', 'u2006'),
 ('u2737', 'u3687'),
 ('u2737', 'u1039'),
 ('u2737', 'u3209'),
 ('u2737', 'u9126'),
 ('u2737', 'u5624'),
 ('u2737', 'u2733'),
 ('u2737', 'u3006'),
 ('u2737', 'u1075'),
 ('u2737', 'u1313'),
 ('u2737', 'u3174'),
 ('u2737', 'u6902'),
 ('u6743', 'u4065'),
 ('u6743', 'u9045'),
 ('u6743', 'u10785'),
 ('u6743', 'u7285'),
 ('u6743', 'u10923'),
 ('u6743', 'u4896'),
 ('u6743', 'u10431'),
 ('u6743', 'u6876'),
 ('u6743', 'u3161'),
 ('u6743', 'u414'),
 ('u6743', 'u2090'),
 ('u6743', 'u9173'),
 ('u6743', 'u8557'),
 ('u6743', 'u256'),
 ('u6743', 'u268'),
 ('u6743', 'u4963'),
 ('u6743', 'u2854'),
 ('u6743', 'u409'),
 ('u6743', 'u703'),
 ('u6743', 'u2284'),
 ('u6743', 'u2522'),
 ('u6743', 'u3142'),
 ('u6743', 'u6172'),
 ('u6743', 'u1069'),
 ('u6743', 'u6651'),
 ('u6743', 'u9724'),
 ('u6743', 'u1481'),
 ('u6743', 'u6985'),
 ('u6743', 'u2947'),
 ('u6743', 'u8826'),
 ('u6743', 'u2735'),
 ('u6743', 'u301'),
 ('u6743', 'u4439'),
 ('u6743', 'u9738'),
 ('u6743', 'u604'),
 ('u6743', 'u1153'),
 ('u6743', 'u1627'),
 ('u6743', 'u723'),
 ('u6743', 'u1113'),
 ('u6743', 'u742'),
 ('u6743', 'u4220'),
 ('u6743', 'u2422'),
 ('u6743', 'u978'),
 ('u6743', 'u2771'),
 ('u6743', 'u2087'),
 ('u6743', 'u3313'),
 ('u6743', 'u1171'),
 ('u6743', 'u1254'),
 ('u6743', 'u921'),
 ('u6743', 'u5604'),
 ('u6743', 'u793'),
 ('u6743', 'u764'),
 ('u6743', 'u4796'),
 ('u6743', 'u7922'),
 ('u6743', 'u2074'),
 ('u6743', 'u10057'),
 ('u6743', 'u1208'),
 ('u6743', 'u1458'),
 ('u6743', 'u1781'),
 ('u6743', 'u9399'),
 ('u6743', 'u1207'),
 ('u6743', 'u2166'),
 ('u6743', 'u9387'),
 ('u6743', 'u3316'),
 ('u6743', 'u2068'),
 ('u6743', 'u4976'),
 ('u6743', 'u3877'),
 ('u6743', 'u298'),
 ('u6743', 'u589'),
 ('u6743', 'u8641'),
 ('u3430', 'u1815'),
 ('u3430', 'u6093'),
 ('u3430', 'u7861'),
 ('u3430', 'u10459'),
 ('u3430', 'u3848'),
 ('u3430', 'u824'),
 ('u3430', 'u6037'),
 ('u3430', 'u2368'),
 ('u3430', 'u1419'),
 ('u3430', 'u1248'),
 ('u3430', 'u361'),
 ('u3430', 'u1012'),
 ('u3430', 'u1645'),
 ('u3430', 'u698'),
 ('u3430', 'u8495'),
 ('u3430', 'u4014'),
 ('u3430', 'u9420'),
 ('u3430', 'u4552'),
 ('u3430', 'u1691'),
 ('u3430', 'u1779'),
 ('u3430', 'u7527'),
 ('u3430', 'u3237'),
 ('u3430', 'u765'),
 ('u3430', 'u1662'),
 ('u3430', 'u1697'),
 ('u3430', 'u1159'),
 ('u3430', 'u5456'),
 ('u3430', 'u2516'),
 ('u3430', 'u7455'),
 ('u3430', 'u10180'),
 ('u3430', 'u402'),
 ('u3430', 'u1898'),
 ('u9575', 'u7649'),
 ('u9575', 'u10684'),
 ('u9575', 'u8445'),
 ('u9575', 'u6456'),
 ('u9575', 'u4046'),
 ('u9575', 'u1947'),
 ('u9575', 'u7785'),
 ('u6603', 'u1629'),
 ('u6603', 'u934'),
 ('u6603', 'u3360'),
 ('u6603', 'u272'),
 ('u6603', 'u10618'),
 ('u9971', 'u627'),
 ('u6367', 'u2173'),
 ('u6367', 'u9705'),
 ('u6367', 'u3110'),
 ('u6367', 'u7456'),
 ('u6367', 'u10704'),
 ('u6367', 'u9915'),
 ('u6367', 'u10745'),
 ('u6367', 'u633'),
 ('u6367', 'u7483'),
 ('u6367', 'u2243'),
 ('u6367', 'u2208'),
 ('u6367', 'u157'),
 ('u6367', 'u942'),
 ('u6367', 'u9781'),
 ('u6367', 'u637'),
 ('u6367', 'u41'),
 ('u6367', 'u1180'),
 ('u6367', 'u356'),
 ('u6367', 'u5350'),
 ('u6367', 'u3492'),
 ('u6367', 'u4939'),
 ('u6367', 'u9329'),
 ('u6367', 'u524'),
 ('u6367', 'u4675'),
 ('u6367', 'u10685'),
 ('u6367', 'u215'),
 ('u6367', 'u396'),
 ('u6367', 'u1666'),
 ('u6367', 'u7877'),
 ('u6367', 'u6653'),
 ('u6367', 'u9790'),
 ('u6367', 'u872'),
 ('u6367', 'u1516'),
 ('u6367', 'u3599'),
 ('u6367', 'u8461'),
 ('u6367', 'u7587'),
 ('u6367', 'u5609'),
 ('u6367', 'u10348'),
 ('u6367', 'u9662'),
 ('u6367', 'u6128'),
 ('u6367', 'u10360'),
 ('u6367', 'u4323'),
 ('u6367', 'u2632'),
 ('u6367', 'u1336'),
 ('u6367', 'u115'),
 ('u6367', 'u6691'),
 ('u6367', 'u8024'),
 ('u6367', 'u91'),
 ('u6367', 'u4430'),
 ('u6367', 'u1320'),
 ('u6367', 'u2275'),
 ('u6367', 'u1'),
 ('u6367', 'u6322'),
 ('u6367', 'u3577'),
 ('u6367', 'u2929'),
 ('u6367', 'u8060'),
 ('u6367', 'u1805'),
 ('u6367', 'u7737'),
 ('u6367', 'u2317'),
 ('u6367', 'u4392'),
 ('u6367', 'u4280'),
 ('u6367', 'u2802'),
 ('u6367', 'u1782'),
 ('u6367', 'u1296'),
 ('u6367', 'u673'),
 ('u6367', 'u2848'),
 ('u6367', 'u5676'),
 ('u6367', 'u10913'),
 ('u6367', 'u3703'),
 ('u6367', 'u7679'),
 ('u6367', 'u9890'),
 ('u6367', 'u2311'),
 ('u6367', 'u2937'),
 ('u6367', 'u741'),
 ('u6367', 'u10868'),
 ('u6367', 'u5918'),
 ('u6367', 'u4647'),
 ('u2882', 'u10245'),
 ('u2882', 'u4974'),
 ('u2882', 'u1856'),
 ('u2882', 'u3645'),
 ('u2882', 'u4665'),
 ('u2882', 'u2106'),
 ('u2882', 'u2339'),
 ('u2882', 'u10638'),
 ('u6607', 'u7685'),
 ('u6607', 'u7619'),
 ('u6607', 'u1409'),
 ('u6607', 'u54'),
 ('u6607', 'u5698'),
 ('u6607', 'u4334'),
 ('u6607', 'u1514'),
 ('u6607', 'u2578'),
 ('u6607', 'u6080'),
 ('u6607', 'u10757'),
 ('u6607', 'u1002'),
 ('u6607', 'u3563'),
 ('u6607', 'u5897'),
 ('u6607', 'u7303'),
 ('u6607', 'u4214'),
 ('u6607', 'u1739'),
 ('u6607', 'u3360'),
 ('u6607', 'u479'),
 ('u6607', 'u1188'),
 ('u6607', 'u308'),
 ('u6607', 'u1324'),
 ('u6607', 'u3795'),
 ('u6607', 'u1231'),
 ('u6607', 'u9256'),
 ('u6607', 'u4462'),
 ('u6607', 'u1311'),
 ('u6607', 'u142'),
 ('u6607', 'u7239'),
 ('u6607', 'u6106'),
 ('u6607', 'u2771'),
 ('u6607', 'u52'),
 ('u6607', 'u3858'),
 ('u5822', 'u1081'),
 ('u7074', 'u6957'),
 ('u7074', 'u2136'),
 ('u7074', 'u483'),
 ('u7074', 'u2984'),
 ('u7074', 'u6209'),
 ('u7074', 'u5470'),
 ('u7074', 'u211'),
 ('u37', 'u6162'),
 ('u37', 'u322'),
 ('u37', 'u7782'),
 ('u37', 'u8657'),
 ('u37', 'u1856'),
 ('u37', 'u5630'),
 ('u37', 'u655'),
 ('u37', 'u5593'),
 ('u37', 'u2879'),
 ('u37', 'u5467'),
 ('u37', 'u8637'),
 ('u37', 'u6094'),
 ('u37', 'u4501'),
 ('u37', 'u2084'),
 ('u37', 'u4546'),
 ('u37', 'u2165'),
 ('u37', 'u2381'),
 ('u37', 'u9657'),
 ('u37', 'u8969'),
 ('u37', 'u116'),
 ('u37', 'u845'),
 ('u37', 'u576'),
 ('u37', 'u7251'),
 ('u37', 'u155'),
 ('u37', 'u2274'),
 ('u37', 'u534'),
 ('u37', 'u7881'),
 ('u37', 'u4498'),
 ('u37', 'u4817'),
 ('u37', 'u2279'),
 ('u37', 'u1538'),
 ('u37', 'u1482'),
 ('u37', 'u976'),
 ('u37', 'u6183'),
 ('u37', 'u3269'),
 ('u37', 'u3429'),
 ('u37', 'u2270'),
 ('u37', 'u2447'),
 ('u37', 'u3862'),
 ('u37', 'u2175'),
 ('u37', 'u366'),
 ('u37', 'u5790'),
 ('u37', 'u2008'),
 ('u37', 'u944'),
 ('u37', 'u1116'),
 ('u37', 'u9124'),
 ('u5127', 'u4042'),
 ('u5127', 'u3082'),
 ('u5127', 'u10961'),
 ('u5127', 'u9743'),
 ('u5127', 'u1336'),
 ('u5127', 'u4010'),
 ('u5127', 'u5285'),
 ('u5127', 'u544'),
 ('u5127', 'u6926'),
 ('u5127', 'u2388'),
 ('u5127', 'u10341'),
 ('u5127', 'u6170'),
 ('u5127', 'u1927'),
 ('u5127', 'u6494'),
 ('u5127', 'u5709'),
 ('u5127', 'u733'),
 ('u5127', 'u6421'),
 ('u5127', 'u6776'),
 ('u5127', 'u3544'),
 ('u5127', 'u10960'),
 ('u5127', 'u5093'),
 ('u5127', 'u1814'),
 ('u5127', 'u3337'),
 ('u5127', 'u5397'),
 ('u5127', 'u7557'),
 ('u5127', 'u1324'),
 ('u5127', 'u6300'),
 ('u5127', 'u1350'),
 ('u5127', 'u4927'),
 ('u5127', 'u723'),
 ('u5127', 'u4378'),
 ('u5127', 'u1986'),
 ('u5127', 'u739'),
 ('u5127', 'u4236'),
 ('u5127', 'u4382'),
 ('u5127', 'u3315'),
 ('u2094', 'u3231'),
 ('u2094', 'u796'),
 ('u2094', 'u4970'),
 ('u2094', 'u646'),
 ('u2094', 'u10006'),
 ('u2094', 'u6244'),
 ('u2094', 'u2359'),
 ('u2094', 'u446'),
 ('u2094', 'u5644'),
 ('u2094', 'u797'),
 ('u2094', 'u1513'),
 ('u2094', 'u924'),
 ('u2094', 'u499'),
 ('u2094', 'u2598'),
 ('u2094', 'u837'),
 ('u2094', 'u248'),
 ('u2094', 'u371'),
 ('u2094', 'u737'),
 ('u2094', 'u2213'),
 ('u2094', 'u5138'),
 ('u2094', 'u15'),
 ('u2094', 'u1067'),
 ('u2094', 'u9267'),
 ('u2094', 'u6690'),
 ('u2094', 'u7076'),
 ('u2094', 'u7667'),
 ('u2094', 'u1054'),
 ('u2094', 'u1941'),
 ('u2094', 'u227'),
 ('u2094', 'u8355'),
 ('u2094', 'u5244'),
 ('u2094', 'u765'),
 ('u2094', 'u5681'),
 ('u2094', 'u5085'),
 ('u2094', 'u516'),
 ('u2094', 'u6754'),
 ('u2094', 'u2429'),
 ('u2094', 'u3345'),
 ('u2094', 'u4075'),
 ('u2094', 'u907'),
 ('u2094', 'u8939'),
 ('u2094', 'u298'),
 ('u2094', 'u5731'),
 ('u2094', 'u1057'),
 ('u8302', 'u3844'),
 ('u8302', 'u10616'),
 ('u8302', 'u5359'),
 ('u8302', 'u972'),
 ('u8302', 'u8504'),
 ('u8302', 'u7392'),
 ('u8302', 'u1850'),
 ('u8302', 'u10002'),
 ('u8302', 'u2171'),
 ('u8302', 'u3449'),
 ('u8302', 'u10340'),
 ('u8302', 'u655'),
 ('u8302', 'u10778'),
 ('u8302', 'u1416'),
 ('u8302', 'u5741'),
 ('u8302', 'u3939'),
 ('u8302', 'u6341'),
 ('u8302', 'u1959'),
 ('u8302', 'u4788'),
 ('u8302', 'u1324'),
 ('u8302', 'u8351'),
 ('u8302', 'u9855'),
 ('u8302', 'u8845'),
 ('u8302', 'u5778'),
 ('u8302', 'u1122'),
 ('u8302', 'u9615'),
 ('u8302', 'u2832'),
 ('u8302', 'u1124'),
 ('u6064', 'u325'),
 ('u6064', 'u2445'),
 ('u6064', 'u1374'),
 ('u6064', 'u6833'),
 ('u6064', 'u6266'),
 ('u6064', 'u8776'),
 ('u6064', 'u6785'),
 ('u6064', 'u2884'),
 ('u6064', 'u9043'),
 ('u6064', 'u6415'),
 ('u6064', 'u3604'),
 ('u6064', 'u3918'),
 ('u6064', 'u6618'),
 ('u6064', 'u10409'),
 ('u6064', 'u5033'),
 ('u6064', 'u4057'),
 ('u6064', 'u5256'),
 ('u6064', 'u4401'),
 ('u6064', 'u4313'),
 ('u6064', 'u6234'),
 ('u6064', 'u7876'),
 ('u6064', 'u83'),
 ('u6064', 'u6164'),
 ('u6064', 'u1135'),
 ('u6064', 'u7349'),
 ('u6064', 'u6219'),
 ('u6064', 'u1385'),
 ('u6064', 'u211'),
 ('u9031', 'u784'),
 ('u9031', 'u96'),
 ('u9031', 'u3305'),
 ('u9031', 'u8303'),
 ('u9031', 'u7456'),
 ('u9031', 'u1539'),
 ('u9031', 'u1438'),
 ('u9031', 'u3187'),
 ('u9031', 'u947'),
 ('u9031', 'u3504'),
 ('u9031', 'u9293'),
 ('u9031', 'u8677'),
 ('u9031', 'u1679'),
 ('u9031', 'u6007'),
 ('u9031', 'u7893'),
 ('u9031', 'u3228'),
 ('u9031', 'u1887'),
 ('u9031', 'u1656'),
 ('u9031', 'u8420'),
 ('u9031', 'u3254'),
 ('u9031', 'u7829'),
 ('u9031', 'u5089'),
 ('u9031', 'u7962'),
 ('u9031', 'u8023'),
 ('u9031', 'u3992'),
 ('u9031', 'u4939'),
 ('u9031', 'u2931'),
 ('u9031', 'u89'),
 ('u9031', 'u1031'),
 ('u9031', 'u6488'),
 ('u9031', 'u6817'),
 ('u9031', 'u1264'),
 ('u9031', 'u8272'),
 ('u9031', 'u6381'),
 ('u9031', 'u1151'),
 ('u9031', 'u7337'),
 ('u9031', 'u3404'),
 ('u9031', 'u1659'),
 ('u9031', 'u3929'),
 ('u9031', 'u1774'),
 ('u9031', 'u6305'),
 ('u9031', 'u922'),
 ('u9031', 'u5124'),
 ('u9031', 'u3993'),
 ('u9031', 'u10713'),
 ('u9031', 'u422'),
 ('u9031', 'u9744'),
 ('u9031', 'u7360'),
 ('u9031', 'u6676'),
 ('u9031', 'u1573'),
 ('u9031', 'u4263'),
 ('u9031', 'u1933'),
 ('u9031', 'u4495'),
 ('u9031', 'u997'),
 ('u9031', 'u3075'),
 ('u9031', 'u7862'),
 ('u9031', 'u7546'),
 ('u9031', 'u1103'),
 ('u9031', 'u1118'),
 ('u9031', 'u10392'),
 ('u9031', 'u2736'),
 ('u9031', 'u135'),
 ('u9031', 'u3700'),
 ('u9031', 'u8743'),
 ('u9031', 'u5461'),
 ('u9031', 'u787'),
 ('u9031', 'u574'),
 ('u9031', 'u8132'),
 ('u9031', 'u7063'),
 ('u9031', 'u3597'),
 ('u9031', 'u208'),
 ('u9031', 'u862'),
 ('u9031', 'u134'),
 ('u9031', 'u4463'),
 ('u9031', 'u1577'),
 ('u9031', 'u7800'),
 ('u9031', 'u64'),
 ('u9031', 'u505'),
 ('u9031', 'u2160'),
 ('u9031', 'u376'),
 ('u9031', 'u10851'),
 ('u9031', 'u2812'),
 ('u9031', 'u1682'),
 ('u9031', 'u5318'),
 ('u9031', 'u5044'),
 ('u9031', 'u4740'),
 ('u9031', 'u1910'),
 ('u9031', 'u4373'),
 ('u9031', 'u2955'),
 ('u9031', 'u1294'),
 ('u9031', 'u6761'),
 ('u9031', 'u6758'),
 ('u9031', 'u2368'),
 ('u9031', 'u2092'),
 ('u9031', 'u1345'),
 ('u9031', 'u10083'),
 ('u9031', 'u2008'),
 ('u9031', 'u7544'),
 ('u9031', 'u268'),
 ('u9031', 'u10632'),
 ('u9031', 'u7148'),
 ('u9031', 'u10821'),
 ('u9031', 'u664'),
 ('u9031', 'u2606'),
 ('u9031', 'u7588'),
 ('u9031', 'u1673'),
 ('u9031', 'u284'),
 ('u9031', 'u5473'),
 ('u9031', 'u8655'),
 ('u9031', 'u2224'),
 ('u9031', 'u3649'),
 ('u9031', 'u215'),
 ('u9031', 'u533'),
 ('u9031', 'u3045'),
 ('u9031', 'u1145'),
 ('u9031', 'u534'),
 ('u9031', 'u3089'),
 ('u9031', 'u3912'),
 ('u9031', 'u2312'),
 ('u9031', 'u6413'),
 ('u9031', 'u198'),
 ('u9031', 'u696'),
 ('u9031', 'u9060'),
 ('u9031', 'u10827'),
 ('u9031', 'u332'),
 ('u9031', 'u2046'),
 ('u9031', 'u8487'),
 ('u9031', 'u1318'),
 ('u9031', 'u2630'),
 ('u9031', 'u1549'),
 ('u9031', 'u1391'),
 ('u9031', 'u1485'),
 ('u9031', 'u1194'),
 ('u9031', 'u7333'),
 ('u9031', 'u6016'),
 ('u9031', 'u8601'),
 ('u9031', 'u2169'),
 ('u9031', 'u1204'),
 ('u9031', 'u1422'),
 ('u9031', 'u5411'),
 ('u9031', 'u1844'),
 ('u9031', 'u1623'),
 ('u9031', 'u7642'),
 ('u9031', 'u5610'),
 ('u9031', 'u1121'),
 ('u9031', 'u5563'),
 ('u9031', 'u5273'),
 ('u9031', 'u2476'),
 ('u9031', 'u4734'),
 ('u9031', 'u2429'),
 ('u9031', 'u4512'),
 ('u9031', 'u437'),
 ('u9031', 'u10476'),
 ('u9031', 'u5899'),
 ('u9031', 'u55'),
 ('u9031', 'u4513'),
 ('u9031', 'u4904'),
 ('u9031', 'u211'),
 ('u9031', 'u5084'),
 ('u9031', 'u1405'),
 ('u9031', 'u100'),
 ('u9031', 'u9357'),
 ('u9031', 'u195'),
 ('u9031', 'u8664'),
 ('u9031', 'u1731'),
 ('u4808', 'u711'),
 ('u4808', 'u279'),
 ('u4808', 'u142'),
 ('u4808', 'u1243'),
 ('u4808', 'u3498'),
 ('u4808', 'u8775'),
 ('u4808', 'u3080'),
 ('u4808', 'u646'),
 ('u4466', 'u7126'),
 ('u583', 'u731'),
 ('u583', 'u5300'),
 ('u583', 'u1230'),
 ('u583', 'u53'),
 ('u302', 'u4875'),
 ('u302', 'u1047'),
 ('u302', 'u1799'),
 ('u302', 'u8569'),
 ('u302', 'u4159'),
 ('u3664', 'u3110'),
 ('u3664', 'u3662'),
 ('u3664', 'u5171'),
 ('u3664', 'u220'),
 ('u3664', 'u4946'),
 ('u3664', 'u3851'),
 ('u3664', 'u797'),
 ('u3664', 'u537'),
 ('u3664', 'u4634'),
 ('u3664', 'u2479'),
 ('u3664', 'u1943'),
 ('u3664', 'u6459'),
 ('u3664', 'u1250'),
 ('u3664', 'u8122'),
 ('u3664', 'u9139'),
 ('u3664', 'u1247'),
 ('u733', 'u4236'),
 ('u733', 'u1618'),
 ('u733', 'u3610'),
 ('u733', 'u1458'),
 ('u733', 'u5835'),
 ('u733', 'u6577'),
 ('u733', 'u349'),
 ('u733', 'u6776'),
 ('u733', 'u1149'),
 ('u733', 'u8616'),
 ('u733', 'u115'),
 ('u733', 'u3243'),
 ('u733', 'u2968'),
 ('u733', 'u8342'),
 ('u733', 'u1415'),
 ('u733', 'u6170'),
 ('u733', 'u1350'),
 ('u733', 'u9974'),
 ('u733', 'u4071'),
 ('u733', 'u4088'),
 ('u733', 'u3337'),
 ('u733', 'u2358'),
 ('u733', 'u723'),
 ('u733', 'u7557'),
 ('u733', 'u5267'),
 ('u733', 'u3258'),
 ('u733', 'u7001'),
 ('u733', 'u9743'),
 ('u733', 'u5285'),
 ('u733', 'u4769'),
 ('u733', 'u3650'),
 ('u733', 'u1336'),
 ('u733', 'u10341'),
 ('u733', 'u336'),
 ('u733', 'u444'),
 ('u733', 'u3544'),
 ('u733', 'u5948'),
 ('u733', 'u6077'),
 ('u733', 'u5093'),
 ('u733', 'u501'),
 ('u733', 'u1814'),
 ('u733', 'u326'),
 ('u733', 'u324'),
 ('u733', 'u2282'),
 ('u733', 'u7692'),
 ('u733', 'u10519'),
 ('u733', 'u8734'),
 ('u733', 'u9670'),
 ('u733', 'u5397'),
 ('u733', 'u5194'),
 ('u733', 'u9801'),
 ('u733', 'u1986'),
 ('u733', 'u569'),
 ('u733', 'u2771'),
 ('u733', 'u4382'),
 ('u733', 'u3315'),
 ('u733', 'u6988'),
 ('u733', 'u4042'),
 ('u733', 'u3082'),
 ('u733', 'u10961'),
 ('u733', 'u4259'),
 ('u733', 'u4010'),
 ('u733', 'u4378'),
 ('u733', 'u6926'),
 ('u733', 'u667'),
 ('u733', 'u5625'),
 ('u733', 'u1876'),
 ('u733', 'u4207'),
 ('u733', 'u3040'),
 ('u733', 'u2410'),
 ('u733', 'u748'),
 ('u733', 'u4677'),
 ('u733', 'u719'),
 ('u733', 'u5152'),
 ('u733', 'u40'),
 ('u733', 'u5994'),
 ('u733', 'u5943'),
 ('u733', 'u2404'),
 ('u733', 'u2120'),
 ('u733', 'u6300'),
 ('u733', 'u4927'),
 ('u733', 'u332'),
 ('u733', 'u6207'),
 ('u733', 'u380'),
 ('u733', 'u739'),
 ('u733', 'u4185'),
 ('u733', 'u3331'),
 ('u733', 'u3361'),
 ('u733', 'u913'),
 ('u733', 'u5423'),
 ('u733', 'u4851'),
 ('u733', 'u2046'),
 ('u733', 'u544'),
 ('u733', 'u5709'),
 ('u733', 'u2388'),
 ('u733', 'u1163'),
 ('u733', 'u8022'),
 ('u733', 'u104'),
 ('u733', 'u5070'),
 ('u733', 'u10529'),
 ('u733', 'u2497'),
 ('u733', 'u6421'),
 ('u733', 'u3233'),
 ('u733', 'u5077'),
 ('u733', 'u10960'),
 ('u733', 'u1927'),
 ('u733', 'u16'),
 ('u733', 'u1797'),
 ('u733', 'u981'),
 ('u733', 'u1324'),
 ('u733', 'u7459'),
 ('u733', 'u5001'),
 ('u733', 'u608'),
 ('u733', 'u5191'),
 ('u733', 'u6494'),
 ('u733', 'u9845'),
 ('u733', 'u6132'),
 ('u733', 'u2644'),
 ('u733', 'u195'),
 ('u733', 'u1057'),
 ('u5740', 'u2230'),
 ('u5740', 'u2730'),
 ('u5740', 'u1294'),
 ('u5740', 'u4853'),
 ('u5740', 'u3405'),
 ('u5740', 'u133'),
 ('u5740', 'u2263'),
 ('u5740', 'u3989'),
 ('u5740', 'u935'),
 ('u5740', 'u1003'),
 ('u5740', 'u21'),
 ('u5740', 'u8783'),
 ('u5740', 'u6955'),
 ('u5740', 'u8992'),
 ('u5740', 'u4256'),
 ('u5740', 'u1978'),
 ('u5740', 'u1940'),
 ('u5740', 'u8729'),
 ('u5740', 'u5040'),
 ('u5740', 'u368'),
 ('u5740', 'u272'),
 ('u5740', 'u4176'),
 ('u5740', 'u5895'),
 ('u5740', 'u5470'),
 ('u5740', 'u10143'),
 ('u5740', 'u8722'),
 ('u5740', 'u280'),
 ('u5740', 'u8647'),
 ('u5740', 'u621'),
 ('u5740', 'u4593'),
 ('u5740', 'u2583'),
 ('u5740', 'u1045'),
 ('u5740', 'u7251'),
 ('u5740', 'u1436'),
 ('u5740', 'u3274'),
 ('u5740', 'u4071'),
 ('u5740', 'u161'),
 ('u5740', 'u8137'),
 ('u5740', 'u844'),
 ('u5740', 'u3509'),
 ('u5740', 'u4189'),
 ('u5740', 'u340'),
 ('u5740', 'u876'),
 ('u5740', 'u8518'),
 ('u5740', 'u5604'),
 ('u5740', 'u4392'),
 ('u5740', 'u2644'),
 ('u5740', 'u9558'),
 ('u5740', 'u357'),
 ('u5740', 'u88'),
 ('u5740', 'u1259'),
 ('u5740', 'u5731'),
 ('u5740', 'u2056'),
 ('u5740', 'u3415'),
 ('u5740', 'u774'),
 ('u5740', 'u7431'),
 ('u5740', 'u5316'),
 ('u5740', 'u4872'),
 ('u5740', 'u5167'),
 ('u5740', 'u9766'),
 ('u5740', 'u7107'),
 ('u5740', 'u1649'),
 ('u5740', 'u2182'),
 ('u5740', 'u592'),
 ('u5740', 'u84'),
 ('u5740', 'u3421'),
 ('u1569', 'u8577'),
 ('u1569', 'u2598'),
 ('u1569', 'u2814'),
 ('u1569', 'u4118'),
 ('u1569', 'u2026'),
 ('u1569', 'u2624'),
 ('u1569', 'u6718'),
 ('u1569', 'u405'),
 ('u1569', 'u16'),
 ('u1569', 'u446'),
 ('u1569', 'u2863'),
 ('u1569', 'u7014'),
 ('u1569', 'u3319'),
 ('u1569', 'u6155'),
 ('u1569', 'u89'),
 ('u1569', 'u1183'),
 ('u1569', 'u941')]

# %%
G = nx.Graph()                   # Initialize an empty graph
G.add_nodes_from(nodes)          # Adds Nodes to the graph
G.add_edges_from(edges)          # Adds Edges to the graph|

# %%
len(G.nodes())
# Out:
# 881

# %%
len(G.edges())
# Out:
# 1000

# %% [markdown]
# ## II. Visualization

# %%
# Plot the degree distribution of the GitHub collaboration network
plt.hist(list(nx.degree_centrality(G).values()))
plt.show()

# %%
# Plot the degree distribution of the GitHub collaboration network
plt.hist(list(nx.degree_centrality(G).values()))
plt.show()

# %%
plt.hist(list(nx.betweenness_centrality(G).values()))
plt.hist(list(nx.degree_centrality(G).values()))
plt.show()

# %%
# Import necessary modules
from nxviz import MatrixPlot
import matplotlib.pyplot as plt

# Calculate the largest connected component subgraph: largest_ccs
largest_ccs = sorted(nx.connected_component_subgraphs(G), key=lambda x: len(x))[-1]

# Create the customized MatrixPlot object: h
h = MatrixPlot(graph = largest_ccs)

# Draw the MatrixPlot to the screen
h.draw()
plt.show()

# %%
# Import necessary modules
from nxviz.plots import ArcPlot
import matplotlib.pyplot as plt

# Iterate over all the nodes in G, including the metadata
for n, d in G.nodes(data = True):

    # Calculate the degree of each node: G.node[n]['degree']
    G.node[n]['degree'] = nx.degree(G, n)
    
# Create the ArcPlot object: a
a = ArcPlot(graph = G, node_order = 'degree', labels = True)

# Draw the ArcPlot to the screen
plt.figure(figsize=(2,2))
a.draw()
plt.show()

# %% [markdown]
# **Note:** You can observe that most of the nodes are tightly connected to each other.
#
# Arc Plot is great for visualizing the Graph with medium number of edges. In addition to adding to plotting the arcs, the above code snippet should also display the nodes. The nodes are actually plotted in the above graph but are too small to notice.
#
# So, we plot the edges and nodes with an alternative plot, the `Circos Plot`.

# %%
# Import necessary modules
from nxviz import CircosPlot
import matplotlib.pyplot as plt 
 
# Iterate over all the nodes, including the metadata
for n, d in G.nodes(data = True):

    # Calculate the degree of each node: G.node[n]['degree']
    G.node[n]['degree'] = nx.degree(G, n)

# Create the CircosPlot object: c
c = CircosPlot(graph = G, node_order = 'degree')

# Draw the CircosPlot object to the screen
c.draw()
plt.show()

# %% [markdown]
# ** Note:** The blue circle that the arcs are surrounded by is not a circle. They are the collection of nodes highlighted in Blue.

# %% [markdown]
# ## III. Cliques:

# %% [markdown]
# **Cliques** are "groups of nodes that are fully connected to one another".
#
# A **Maximal Clique** is a clique that cannot be extended by adding another node in the graph.

# %%
# Calculate the maximal cliques in G: cliques
cliques = nx.find_cliques(G)

# Count and print the number of maximal cliques in G
print(cliques)
# Out:
# <generator object find_cliques at 0x000000000BB81A98>

# %%
list(cliques)
# Out:
# [['u1458', 'u6743'],
#  ['u1458', 'u733'],
#  ['u7821', 'u3879'],
#  ['u7821', 'u7252'],
#  ['u2644', 'u7644', 'u5740'],
#  ['u2644', 'u733'],
#  ['u793', 'u6743'],
#  ['u5467', 'u37'],
#  ['u7392', 'u8302'],
#  ['u10918', 'u7326'],
#  ['u6322', 'u6367'],
#  ['u1799', 'u302'],
#  ['u9802', 'u10110'],
#  ['u5835', 'u733'],
#  ['u737', 'u2094'],
#  ['u3498', 'u4808'],
#  ['u2984', 'u7074'],
#  ['u4065', 'u6743'],
#  ['u537', 'u3664'],
#  ['u5300', 'u583'],
#  ['u3231', 'u2094'],
#  ['u9724', 'u6743'],
#  ['u1566', 'u1221'],
#  ['u8122', 'u3664'],
#  ['u935', 'u7644', 'u5740'],
#  ['u9614', 'u7326'],
#  ['u2381', 'u37'],
#  ['u357', 'u7644', 'u5740'],
#  ['u8969', 'u37'],
#  ['u4088', 'u733'],
#  ['u4665', 'u2882'],
#  ['u10785', 'u6743'],
#  ['u5167', 'u7644', 'u5740'],
#  ['u2006', 'u2737'],
#  ['u2884', 'u6064'],
#  ['u10618', 'u6603'],
#  ['u5948', 'u733'],
#  ['u637', 'u6367'],
#  ['u9173', 'u6743'],
#  ['u6128', 'u6367'],
#  ['u7644', 'u5740', 'u6955'],
# ...

# %%
# Import necessary modules
import networkx as nx
from nxviz import CircosPlot
import matplotlib.pyplot as plt

# Find the author(s) that are part of the largest maximal clique: largest_clique
largest_clique = sorted(nx.find_cliques(G), key=lambda x:len(x))[-1]

# Create the subgraph of the largest_clique: G_lc
G_lc = G.subgraph(largest_clique)

# Create the CircosPlot object: c
c = CircosPlot(G_lc)

# Draw the CircosPlot to the screen
c.draw()
plt.show()

# %% [markdown]
# The above plot denotes that the maximum number of nodes in a clique is 3. Though the edges are not visible to the eye, when zoomed in, the plot looks something like this:
#
# <img src = "img/Cliques.png">
#
# **Note:** There's a thin line(Edge) connecting each node.

# %% [markdown]
# ## IV. Building Recommendation System:
#
# - Find Important Users (Degree Centrality)
# - Find Largest Communities of Collaborators (Maximal Clique)
# - Build a collaboration recommendsation system (Open Triangle)

# %%
# Compute the degree centralities of G: deg_cent
deg_cent = nx.degree_centrality(G)

# Compute the maximum degree centrality: max_dc
max_dc = max(deg_cent.values())

# Find the user(s) that have collaborated the most: prolific_collaborators
prolific_collaborators = [n for n, dc in deg_cent.items() if dc == max_dc]

# Print the most prolific collaborator(s)
print(prolific_collaborators)
# Out:
# ['u9031']

# %%
# Import necessary modules
from nxviz import ArcPlot
import matplotlib.pyplot as plt
 
# Identify the largest maximal clique: largest_max_clique
largest_max_clique = set(sorted(nx.find_cliques(G), key=lambda x: len(x))[-1])

# Create a subgraph from the largest_max_clique: G_lmc
G_lmc = G.subgraph(largest_max_clique)

# Go out 1 degree of separation
for node in G_lmc.nodes():
    G_lmc.add_nodes_from(G.neighbors(node))
    G_lmc.add_edges_from(zip([node]*len(G.neighbors(node)), G.neighbors(node)))

# Record each node's degree centrality score
for n in G_lmc.nodes():
    G_lmc.node[n]['degree centrality'] = nx.degree_centrality(G_lmc)[n]
        
# Create the ArcPlot object: a
a = ArcPlot(G_lmc)

# Draw the ArcPlot to the screen
a.draw()
plt.show()

# %% [markdown]
# NetworkX 2.6 (current version) does not support mutation of Sub Graphs which is supported by earlier versions of NetworkX
#
# <img src = "img/Largest_Communities.png">

# %%
# Import necessary modules
from itertools import combinations
from collections import defaultdict

# Initialize the defaultdict: recommended
recommended = defaultdict(int)

# Iterate over all the nodes in G
for n, d in G.nodes(data = True):

    # Iterate over all possible triangle relationship combinations
    for n1, n2 in combinations(G.neighbors(n), 2):
    
        # Check whether n1 and n2 do not have an edge
        if not G.has_edge(n1, n2):
        
            # Increment recommended
            recommended[(n1, n2)] += 1

# Identify the top 10 pairs of users
all_counts = sorted(recommended.values())
top10_pairs = [pair for pair, count in recommended.items() if count > all_counts[-10]]
print(top10_pairs)
# Out:
# [('u4071', 'u2644'), ('u6743', 'u733'), ('u6367', 'u9031'), ('u9031', 'u733')]

# %% [markdown]
# **Notes:** Above are the top 4 user pairs that should collaborate together according to the recommendation system.
